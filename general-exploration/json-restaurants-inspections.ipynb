# %% [markdown]
# # NYC Restaurant Inspection Results

# %%
import pandas as pd
from sodapy import Socrata
from config import API_Key, username, password
import requests
import json
import matplotlib.pyplot as plt
import re, datetime

from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.io import show, output_notebook
from bokeh.transform import dodge
from bokeh.core.properties import value

# %% [markdown]
# ## 1. Loading Data from API

# %%
# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us", API_Key, username, password)

# Returned as JSON from API by sodapy.
data = client.get("43nn-pn8j",limit=381912)

# Convert to pandas DataFrame
data_df = pd.DataFrame.from_records(data)

# %%
data_df.head(20)
# Out:
#                                              action      boro building  \
# 0   Violations were cited in the following area(s).     BRONX     1007
# 1   Violations were cited in the following area(s).     BRONX     1007
# 2   Violations were cited in the following area(s).     BRONX     1007
# 3   Violations were cited in the following area(s).     BRONX     1007
# 4   Violations were cited in the following area(s).     BRONX     1007
# 5   Violations were cited in the following area(s).     BRONX     1007
# 6   Violations were cited in the following area(s).  BROOKLYN      469
# 7   Violations were cited in the following area(s).  BROOKLYN      469
# 8   Violations were cited in the following area(s).  BROOKLYN      469
# 9   Violations were cited in the following area(s).  BROOKLYN      469
# 10  Violations were cited in the following area(s).  BROOKLYN      469
# 11  Violations were cited in the following area(s).  BROOKLYN      469
# 12  Violations were cited in the following area(s).  BROOKLYN      469
# 13  Violations were cited in the following area(s).  BROOKLYN      469
# 14  Violations were cited in the following area(s).  BROOKLYN      469
# 15  Violations were cited in the following area(s).  BROOKLYN      469
# 16  Violations were cited in the following area(s).  BROOKLYN      469
# 17  Violations were cited in the following area(s).  BROOKLYN      469
# 18  Violations were cited in the following area(s).  BROOKLYN      469
# 19  Violations were cited in the following area(s).  BROOKLYN      469
#
#        camis critical_flag cuisine_description                    dba grade  \
# 0   30075445  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 1   30075445  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 2   30075445      Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 3   30075445  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 4   30075445      Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 5   30075445  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 6   30112340      Critical          Hamburgers                WENDY'S     A
# 7   30112340  Not Critical          Hamburgers                WENDY'S     A
# 8   30112340  Not Critical          Hamburgers                WENDY'S     A
# 9   30112340      Critical          Hamburgers                WENDY'S     A
# 10  30112340  Not Critical          Hamburgers                WENDY'S     A
# 11  30112340  Not Critical          Hamburgers                WENDY'S     A
# 12  30112340      Critical          Hamburgers                WENDY'S     A
# 13  30112340  Not Critical          Hamburgers                WENDY'S     A
# 14  30112340      Critical          Hamburgers                WENDY'S   NaN
# 15  30112340      Critical          Hamburgers                WENDY'S     A
# 16  30112340  Not Critical          Hamburgers                WENDY'S     A
# 17  30112340      Critical          Hamburgers                WENDY'S   NaN
# 18  30112340      Critical          Hamburgers                WENDY'S   NaN
# 19  30112340      Critical          Hamburgers                WENDY'S   NaN
#
#                  grade_date          inspection_date  \
# 0   2018-05-11T00:00:00.000  2018-05-11T00:00:00.000
# 1   2018-05-11T00:00:00.000  2018-05-11T00:00:00.000
# 2   2017-05-18T00:00:00.000  2017-05-18T00:00:00.000
# 3   2017-05-18T00:00:00.000  2017-05-18T00:00:00.000
# 4   2016-02-18T00:00:00.000  2016-02-18T00:00:00.000
# 5   2016-02-18T00:00:00.000  2016-02-18T00:00:00.000
# 6   2019-03-04T00:00:00.000  2019-03-04T00:00:00.000
# 7   2019-03-04T00:00:00.000  2019-03-04T00:00:00.000
# 8   2019-03-04T00:00:00.000  2019-03-04T00:00:00.000
# 9   2018-03-13T00:00:00.000  2018-03-13T00:00:00.000
# 10  2018-03-13T00:00:00.000  2018-03-13T00:00:00.000
# 11  2018-03-13T00:00:00.000  2018-03-13T00:00:00.000
# 12  2017-10-06T00:00:00.000  2017-10-06T00:00:00.000
# 13  2017-10-06T00:00:00.000  2017-10-06T00:00:00.000
# 14                      NaN  2017-06-26T00:00:00.000
# 15  2016-10-27T00:00:00.000  2016-10-27T00:00:00.000
# 16  2016-10-27T00:00:00.000  2016-10-27T00:00:00.000
# 17                      NaN  2016-10-03T00:00:00.000
# 18                      NaN  2016-10-03T00:00:00.000
# 19                      NaN  2016-10-03T00:00:00.000
#
#                           inspection_type       phone  \
# 0   Cycle Inspection / Initial Inspection  7188924968
# 1   Cycle Inspection / Initial Inspection  7188924968
# 2   Cycle Inspection / Initial Inspection  7188924968
# 3   Cycle Inspection / Initial Inspection  7188924968
# 4   Cycle Inspection / Initial Inspection  7188924968
# 5   Cycle Inspection / Initial Inspection  7188924968
# 6   Cycle Inspection / Initial Inspection  7182875005
# 7   Cycle Inspection / Initial Inspection  7182875005
# 8   Cycle Inspection / Initial Inspection  7182875005
# 9   Cycle Inspection / Initial Inspection  7182875005
# 10  Cycle Inspection / Initial Inspection  7182875005
# 11  Cycle Inspection / Initial Inspection  7182875005
# 12       Cycle Inspection / Re-inspection  7182875005
# 13       Cycle Inspection / Re-inspection  7182875005
# 14  Cycle Inspection / Initial Inspection  7182875005
# 15       Cycle Inspection / Re-inspection  7182875005
# 16       Cycle Inspection / Re-inspection  7182875005
# 17  Cycle Inspection / Initial Inspection  7182875005
# 18  Cycle Inspection / Initial Inspection  7182875005
# 19  Cycle Inspection / Initial Inspection  7182875005
#
#                 record_date score           street violation_code  \
# 0   2019-05-01T06:00:34.000     5  MORRIS PARK AVE            08C
# 1   2019-05-01T06:00:34.000     5  MORRIS PARK AVE            10F
# 2   2019-05-01T06:00:34.000     7  MORRIS PARK AVE            06D
# 3   2019-05-01T06:00:34.000     7  MORRIS PARK AVE            10F
# 4   2019-05-01T06:00:34.000    10  MORRIS PARK AVE            04L
# 5   2019-05-01T06:00:34.000    10  MORRIS PARK AVE            08A
# 6   2019-05-01T06:00:34.000    13  FLATBUSH AVENUE            02G
# 7   2019-05-01T06:00:34.000    13  FLATBUSH AVENUE            10B
# 8   2019-05-01T06:00:34.000    13  FLATBUSH AVENUE            10F
# 9   2019-05-01T06:00:34.000    12  FLATBUSH AVENUE            04L
# 10  2019-05-01T06:00:34.000    12  FLATBUSH AVENUE            08A
# 11  2019-05-01T06:00:34.000    12  FLATBUSH AVENUE            10B
# 12  2019-05-01T06:00:34.000    10  FLATBUSH AVENUE            04H
# 13  2019-05-01T06:00:34.000    10  FLATBUSH AVENUE            10F
# 14  2019-05-01T06:00:34.000     7  FLATBUSH AVENUE            04N
# 15  2019-05-01T06:00:34.000    11  FLATBUSH AVENUE            04N
# 16  2019-05-01T06:00:34.000    11  FLATBUSH AVENUE            08A
# 17  2019-05-01T06:00:34.000    48  FLATBUSH AVENUE            04N
# 18  2019-05-01T06:00:34.000    48  FLATBUSH AVENUE            06A
# 19  2019-05-01T06:00:34.000    48  FLATBUSH AVENUE            06C
#
#                                 violation_description zipcode
# 0   Pesticide use not in accordance with label or ...   10462
# 1   Non-food contact surface improperly constructe...   10462
# 2   Food contact surface not properly washed, rins...   10462
# 3   Non-food contact surface improperly constructe...   10462
# 4   Evidence of mice or live mice present in facil...   10462
# 5   Facility not vermin proof. Harborage or condit...   10462
# 6   Cold food item held above 41Âº F (smoked fish ...   11225
# 7   Plumbing not properly installed or maintained;...   11225
# 8   Non-food contact surface improperly constructe...   11225
# 9   Evidence of mice or live mice present in facil...   11225
# 10  Facility not vermin proof. Harborage or condit...   11225
# 11  Plumbing not properly installed or maintained;...   11225
# 12  Raw, cooked or prepared food is adulterated, c...   11225
# 13  Non-food contact surface improperly constructe...   11225
# 14  Filth flies or food/refuse/sewage-associated (...   11225
# 15  Filth flies or food/refuse/sewage-associated (...   11225
# 16  Facility not vermin proof. Harborage or condit...   11225
# 17  Filth flies or food/refuse/sewage-associated (...   11225
# 18  Personal cleanliness inadequate. Outer garment...   11225
# 19  Food not protected from potential source of co...   11225

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381698 entries, 0 to 381697
# Data columns (total 18 columns):
# action                   380361 non-null object
# boro                     381698 non-null object
# building                 381476 non-null object
# camis                    381698 non-null object
# critical_flag            381698 non-null object
# cuisine_description      381698 non-null object
# dba                      381189 non-null object
# grade                    192284 non-null object
# grade_date               189749 non-null object
# inspection_date          381698 non-null object
# inspection_type          380361 non-null object
# phone                    381689 non-null object
# record_date              381698 non-null object
# score                    363480 non-null object
# street                   381698 non-null object
# violation_code           375872 non-null object
# violation_description    373270 non-null object
# zipcode                  376151 non-null object
# dtypes: object(18)
# memory usage: 52.4+ MB

# %% [markdown]
# ## 2. Violations Count by Year and Boroughs

# %%
violation_count = data_df.groupby(['inspection_date','boro'])['violation_code'].count()
violation_count = pd.DataFrame(violation_count)
violation_count = violation_count.reset_index()
violation_count = violation_count.loc[violation_count['boro']!='Missing']
violation_count = violation_count.rename(columns={"violation_code": "violation_count"})
violation_count.head()
# Out:
#            inspection_date           boro  violation_count
# 0  1900-01-01T00:00:00.000          BRONX                0
# 1  1900-01-01T00:00:00.000       BROOKLYN                0
# 2  1900-01-01T00:00:00.000      MANHATTAN                0
# 4  1900-01-01T00:00:00.000         QUEENS                0
# 5  1900-01-01T00:00:00.000  STATEN ISLAND                0

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
violation = violation_count.copy()
violation = violation.pivot(index='inspection_date',columns='boro',values='violation_count')
violation = violation.dropna()
violation = violation.reset_index()
violation.head()
# Out:
# boro          inspection_date  BRONX  BROOKLYN  MANHATTAN  QUEENS  \
# 0     1900-01-01T00:00:00.000    0.0       0.0        0.0     0.0
# 1     2015-04-16T00:00:00.000    0.0       6.0        8.0     3.0
# 2     2015-04-17T00:00:00.000    3.0       8.0       20.0     4.0
# 3     2015-04-30T00:00:00.000    2.0       6.0       14.0    15.0
# 4     2015-05-05T00:00:00.000    4.0       1.0       14.0     5.0
#
# boro  STATEN ISLAND
# 0               0.0
# 1               5.0
# 2               2.0
# 3               1.0
# 4               4.0

# %%
boros = list(violation_count['boro'].unique())

boro_data = []
for boro in boros:
    borough = violation_count.loc[violation_count['boro']==boro]['violation_count']
    boro_data.append(borough)
    
boros
# Out:
# ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']

# %%
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(boro_data)

# Add tickers
ax.set_xticklabels(boros)

# Save the figure #fig.savefig('fig1.png', bbox_inches='tight')
plt.show()

# %%
cuisine_count = data_df.groupby(['cuisine_description'])[['dba','violation_code']].count()
#cuisine_count = pd.DataFrame(violation_count)
#cuisine_count = violation_count.reset_index()
cuisine_count
# Out:
#                                                       dba  violation_code
# cuisine_description
# Afghan                                                168             166
# African                                              1594            1572
# American                                            82327           81209
# Armenian                                              279             273
# Asian                                                6039            5982
# Australian                                            329             326
# Bagels/Pretzels                                      2724            2693
# Bakery                                              11598           11461
# Bangladeshi                                          1066            1049
# Barbecue                                              809             790
# Basque                                                  7               7
# Bottled beverages, including water, sodas, juic...   1227            1188
# Brazilian                                             462             458
# CafÃ©/Coffee/Tea                                    18022           17757
# Cajun                                                  77              77
# Californian                                           112             108
# Caribbean                                           13390           13214
# Chicken                                              6822            6752
# Chilean                                                17              17
# Chinese                                             39660           39243
# Chinese/Cuban                                         367             366
# Chinese/Japanese                                      893             887
# Continental                                           654             647
# Creole                                                568             557
# Creole/Cajun                                           96              95
# Czech                                                  33              33
# Delicatessen                                         6065            5987
# Donuts                                               5178            5118
# Eastern European                                     1304            1290
# Egyptian                                              166             158
# ...                                                   ...             ...
# Middle Eastern                                       2750            2713
# Moroccan                                              154             153
# Not Listed/Not Applicable                             115             115
# Nuts/Confectionary                                     24              22
# Other                                                1995            1310
# Pakistani                                             641             630
# Pancakes/Waffles                                      234             231
# Peruvian                                             1729            1707
# Pizza                                               16966           16766
# Pizza/Italian                                        8383            8284
# Polish                                                523             514
# Portuguese                                            144             143
# Russian                                              1061            1042
# Salads                                                899             894
# Sandwiches                                           4154            4105
# Sandwiches/Salads/Mixed Buffet                       2795            2760
# Scandinavian                                           80              80
# Seafood                                              2951            2921
# Soul Food                                            1117            1100
# Soups                                                  57              56
# Soups & Sandwiches                                    549             547
# Southwestern                                           94              94
# Spanish                                             11500           11371
# Steak                                                1216            1208
# Tapas                                                 526             520
# Tex-Mex                                              1915            1889
# Thai                                                 5080            5030
# Turkish                                              1210            1203
# Vegetarian                                           1755            1745
# Vietnamese/Cambodian/Malaysia                        1791            1770
#
# [84 rows x 2 columns]

# %% [markdown]
# ## 4. Mapping with folium

# %%
map_df = data_df.groupby(['boro','zipcode'])[['dba','inspection_type','violation_code']].count()
map_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 230 entries, (BRONX, 10451) to (STATEN ISLAND, 10314)
# Data columns (total 3 columns):
# dba                230 non-null int64
# inspection_type    230 non-null int64
# violation_code     230 non-null int64
# dtypes: int64(3)
# memory usage: 8.0+ KB
