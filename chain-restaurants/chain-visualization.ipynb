# %% [markdown]
# # Visualizations for NYC Chain Restaurant Inspection Results

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re, datetime

from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.io import show, output_notebook, output_file
from bokeh.transform import dodge
from bokeh.core.properties import value
from bokeh.palettes import Spectral6

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 1. Line Charts

# %%
data = pd.read_csv('camis_tidy.csv')
data.head()
# Out:
#    Unnamed: 0          inspection_date  inspection_year  \
# 0           0  1900-01-01T00:00:00.000             1900
# 1           1  1900-01-01T00:00:00.000             1900
# 2           2  1900-01-01T00:00:00.000             1900
# 3           3  1900-01-01T00:00:00.000             1900
# 4           4  1900-01-01T00:00:00.000             1900
#
#                            dba  camis_count
# 0            18TH WARD BREWPUB            1
# 1                  1942 LOUNGE            1
# 2     207 BAKERY & COFFEE SHOP            1
# 3  23 WINEHOUSE ITALIAN BISTR0            1
# 4             7 TERIYAKI SUSHI            1

# %%
store_num = data.loc[data['inspection_year'] >= 2015]
local = store_num.loc[store_num['camis_count'] <= 100]
print(len(list(local['dba'].unique())))
local_list = list(local['dba'].unique())
local_list
# Out:
# 20479
# ['RELISH CONCESSIONS (LASKER RINK)',
#  'DELMY FOOD',
#  'EL PATRON NIGHTCLUB CABARET-RESTAURANT',
#  'VILLA BARONE',
#  'OLYMPIC PIER CAFE',
#  'HUNAN GLATT KOSHER',
#  'SORRENTINE',
#  '4O KNOTS',
#  "CLAUDINE'S",
#  'GRAND OASIS RESTAURANT',
#  'BAR NONE',
#  'MERRY LAND BUFFET',
#  'BROOKLYN SWEET SPOT',
#  'TERTULIA',
#  'PORTALIA RISTORANTE BAR AND LOUNGE',
#  'RICHMOND COUNTY COUNTRY CLUB',
#  'THEATER CAFE',
#  'NEW POLODOS LOUNGE',
#  'NOVITA',
#  "GIACOMO'S WOOD FIRED PIZZA",
#  "Pinot's Pallette",
#  'SABOR NORTENO',
#  'RICHMOND COUNTY YACHT CLUB',
#  'DESNUDA',
#  'TREADWELL PARK / BLACK HOUND',
#  'THE FINCH',
#  'BEST WESTERN PREMIER HERALD SQUARE',
#  "STEINBERG CENTER THEATER(JODI'S LOUNGE)",
#  "GUSSY'S BAR",
#  'FALAFEL OFF THE CORNER',
#  'KNIGHTS OF COLUMBUS HOUSE',
#  'SHAARE ZION CATERERS',
#  'HUDSON BAR AND BOOKS',
#  'HECHO EN DUMBO',
#  'PHILIPPE NYC I',
#  'ROYAL RIB HOUSE',
#  'POK POK NY',
#  'LE COLONIAL',
#  'VAN LEEUWEN ARTISAN ICE CREAM',
#  'GINA MEXICANA',
#  'MIX',
#  'AGUA ROJA BAR & LOUNGE',
#  'ATWOOD KITCHEN & BAR',
#  'DAVIS FAMILY ESTABLISHMENT',
#  'BLEND',
#  'GREENPOINT TAVERN',
#  'MAISON MAY',
#  'THE BLUE GOOSE',
#  'CAFE DUKE',
#  'NEW YORK UNIVERSITY - PALLADIUM FOOD COURT',
#  "NICKY'S PIZZA",
#  'TROPICAL 128',
#  'WEST 3RD COMMON',
#  "DANIELA'S CAFE",
#  'TEVERE 84',
#  'FAT BUDDHA',
#  'EL PARAISO LOUNGE',
#  'ESME',
#  "LOVELL'S GUIDING LIGHT",
#  'NEW PHOENIX PALACE',
#  'HAN DYNASTY',
#  'LA SORRENTINA RISTORANTE',
#  'MEMBERS DINING ROOM @ THE MET MUSEUM',
#  'MIYAKO SUSHI',
#  'RINGOLEVIO',
#  'THE PAPER BOX',
#  'YANKEE CLIPPER',
#  'EUROS EL TINA RESTAURANT LOUNGE AND BILLIARDS',
#  'PRONTO PIZZA',
#  'KYO-YA',
#  'MAMAN & MIMI NOLITA',
#  'SUZAN KITCHEN',
#  'FOOD KING',
#  'LAVAZZA ESPRESSO BAR',
#  'OUTPUT CLUB',
#  'PILAR CUBAN EATERY',
#  'STARBUCKS',
#  'VIN SUR VINGT',
#  'BAR GREAT HARRY',
#  'DINOSAUR BAR-B-QUE',
#  "LEO'S DELI & GRILL",
#  'PAPA RESTAURANT',
#  'CIRCLE LINE BROOKLYN',
#  'KABAB CAFE',
#  "MUG-Z'S SPORTS BAR",
#  'SOFITEL NEW YORK',
#  'SPICE',
#  'THE BOMOND RESTAURANT',
#  'THE SMITH',
#  'AMC THEATRES',
#  'SECRETS',
#  'MAOZ VEGETARIAN',
#  'THE WOODS/ THE BEAR (BACKYARD)',
#  'TUFFET',
#  'VINTAGE CURRY',
#  'CARROLL PLACE',
#  'EL QUIJOTE',
#  "JUICY LUCY'S",
#  'SWEDISH FOOTBALL CLUB',
#  'EL PORTON BAR & RESTAURANT',
#  'HARMONIE CLUB',
#  'The Big Whiskey',
#  'UNFORGETTABLE LOUNGE',
#  'BAKU PALACE',
#  'CANTINA ROYAL',
#  'SPORTS LUNCHEONETTE',
#  'TAVERN ON THE GREEN',
#  'THE COUNTING ROOM',
#  'THE RUSSIAN TEA ROOM',
#  'THE SIMONE',
#  'THE TANGLED VINE',
#  'PARK AVENUE LUNCHEONETTE',
#  'BLARNEY CASTLE',
#  "DUNKIN' DONUTS",
#  'STILLWATER BAR & GRILL',
#  'THE CLAM',
#  'DA NICO RESTAURANT',
#  'DUE PONTI RISTORANTE ITALIANO',
#  "JOSIE'S BAR",
#  'MERMAID SPORTS BAR',
#  'RATTLE N HUM',
#  "STAN'S SPORTS BAR",
#  'STK',
#  'KI SUSHI',
#  'OMIYA SUSHI II',
#  'PICCOLI TRATTORIA',
#  'BATEAUX NEW YORK',
#  'DOYLES PUB',
#  'EAST DIM SUM',
#  'LATERNA TAVERNA',
#  'POTJANEE',
#  'VIDA',
#  'DEJA VU LOUNGE & BAR',
#  'GOTHAM PIZZA',
#  'NEW PINANG',
#  'BANGAGAN',
#  'BROOKLYN BOWL',
#  'LTK LITTLE THAI KITCHEN',
#  'ROEBLING PIZZA',
#  "E'S BAR",
#  'EASTWOOD MANOR',
#  "MARCELLA'S PIZZERIA & CATERING",
#  "NEW EVERYBODY'S KITCHEN",
#  'WILFIE & NELL',
#  'BAREBURGER',
#  'CAFE LATTE',
#  'LOIS BAR',
#  'MAGNA BAR & RESTAURANT',
#  'BURNSIDE BEER & WINE CAFETERIA',
#  'CAPIZZI',
#  'ROSEBANK TAVERN',
#  'CHEN XIN LUNG CHINESE RESTAURANT',
#  'KNICKERBOCKER CLUB',
#  'MAYFIELD',
#  'NANO',
#  'STARZ BANQUET HALL',
#  'TREE',
#  "VIRGINIA'S",
#  'MELROSE BALLROOM',
#  'SALSA CON FUEGO',
#  'BAMBOO TROPICAL',
#  'DE ISLANDS',
#  'EAGLE CITY TEX MEX CHINESE FOOD',
#  'HONG BAO RESTAURANT',
#  'JUICE AMMIEL',
#  'LA CARBORNARA',
#  'NEW PEKING',
#  "NINA'S RESTAURANT PIZZERIA",
#  'SOCIALE',
#  'SUMA SUSHI',
#  'SUSHI CHOSI',
#  'SUSHI KOI',
#  "BROTHER JIMMY'S BBQ",
#  "DUNKIN' DONUTS, BASKIN ROBBINS",
#  'FAT GOOSE',
#  'GARI',
#  'NITEHAWK CINEMA',
#  'SUNITA',
#  'BEST PIZZA ON 1ST.',
#  'ESTIATORIO MILOS',
#  'FORTY EIGHT LOUNGE',
#  'FULTON CAFE',
#  'INASE SUSHI RESTAURANT',
#  'KETTLE OF FISH',
#  'Kurant',
#  'LITTLE SKIPS',
#  'PROJECT PARLOR',
#  'RAMONA',
#  'cloud social',
#  'BAYRIDGE PIZZA',
#  'BUTTERMILK CHANNEL',
#  "DEACON BRODIE'S",
#  'EAT-A-BAGEL - BOAT SPIRIT OF AMERICA',
#  'HABANERO CAFE MEXICAN GRILL',
#  'JUST MADE SUSHI (DD MARU)',
#  'LE GIGOT',
#  'MAITE',
#  'NEW DYNASTY',
#  'NEW FOOD KING',
#  'SHAKE SHACK',
#  'SPUYTEN DUYVIL',
#  'SWAY LOUNGE',
#  'ZAMAAN HOOKAH BAR',
#  'B.A.M. CAFE/GREAT PERFORMANCES',
#  'CAPRICE',
#  'CHIAN FEDERATION',
#  "DUNKIN' DONUTS/ BASKIN ROBBINS",
#  'GUYANA EX POLICE ASSOCIATION OF AMERICA',
#  'IMPERIAL THEATRE',
#  'LA FONDA DEL SOL',
#  'LOLLIPOPS ICE CREAM',
#  'POLISH NATIONAL HOME',
#  'TANDOOR PALACE',
#  'CB CHARISMA BALLROOM',
#  "FOXY GENTLEMEN'S CLUB",
#  'BLUE RIBBON SUSHI',
#  'CAFE METRO',
#  'LITTLE ITALY M & O PIZZA RESTAURANT',
#  'PRET A MANGER',
#  'SPIRIT OF NEW JERSEY',
#  'WATAWA JAPANESE RESTAURANT',
#  'WORLD YACHT - ST. CHARLES',
#  'BARNES & NOBLE CAFE',
#  'CAFE PARIS',
#  'CHOP CHOP KITCHEN',
#  'CUCINA FRESCA',
#  'ELEGANTE PASTRY SHOP',
#  "Lenny's",
#  'MAX  CAFFE',
#  "O'DONOGHUE'S",
#  'THE HARP',
#  'BARIOS PIZZA & RESTAURANT',
#  'EMPIRE TORTILLAS',
#  'EMPORIO',
#  'El Pollo II Restaurant',
#  'HAPPY FUN HIDEAWAY',
#  "HUNAN ''K'' CHINESE RESTAURANT",
#  'NOREETUH',
#  'SERVICE BAR 5',
#  'SKY TERRACE BAR',
#  'SPIRIT OF NEW YORK',
#  'THE MOONLIGHTMILE',
#  'COBBLE HILL CINEMAS',
#  'EL PITALLITO RESTAURANT',
#  'LA GITANA PANADERIA - RESTAURANTE',
#  'THE WAVERLY INN',
#  'TRANQUILITY BAR & LOUNGE',
#  'YUMMY HOUSE',
#  'BEST WESTERN CONVENTION CENTER',
#  'BUTTERFIELD CATERING',
#  "LENNY'S BAGELS",
#  "NAIDRE'S",
#  'THE SHANTY',
#  'VALBONA RESTAURANT',
#  'VERO',
#  'PEQUENA',
#  'SARILING ATIN',
#  'SHUBERT THEATER',
#  'WEST END BAR & GRILL',
#  'YO-YO FRITAILLE',
#  'DRUNKEN HORSE',
#  'GRAND CAFE (Metropolitan Hospital)',
#  'GREENPOINT DELI',
#  'HABANA OUTPOST',
#  "LUCY'S VIETNAMESE KITCHEN",
#  'MARINA CAFE',
#  'SOUTH SHORE LITTLE LEAGUE CONCESION STAND',
#  'THE GREEK KITCHEN  CLINTON BAKERY CAFE',
#  "THOMASINA'S CATERING HALL",
#  'FORNINO',
#  'LOUNGE BAR CAVE',
#  'STATEN ISLAND 16 THEATRE',
#  'TAAM MEVORACH',
#  'THE ONENESS FOUNTAIN HEART',
#  'AL HORNO LEAN MEXICAN KITCHEN INC',
#  'BOWLER LAND',
#  'CAFE ARTE',
#  'METRO STAR COFFEE SHOP',
#  'MY KITCHEN',
#  'PIER 60',
#  'MACE',
#  'PAULIE GEE',
#  'PELHAM BAY DINER',
#  'CHIPOTLE MEXICAN GRILL',
#  'HERO CHAMP',
#  'ISLAND RAGE',
#  'PRANZO',
#  'CHINA PAGODA',
#  'JADE PALACE',
#  'MID CHINA',
#  'MIN JIANG MINI CAFE',
#  'RANDOLPH BEER',
#  "GINO'S PIZZA EXPRESS",
#  'Great Wall',
#  'HARD TIMES',
#  'KINFOLK',
#  'KORALI ESTIATORIO',
#  'PIECES',
#  'ROCKWAY BEACH CLUB',
#  "SHASHEMENE INT'L RESTAURANT",
#  'SUBWAY',
#  'TAGLIERE',
#  'BALLFIELDS CAFE',
#  'CIAO FOR NOW',
#  'CUBBYHOLE',
#  'GOMI-WINE-FOOD-FRIENDS',
#  'SIENA',
#  'SWEET EXPRESSIONS',
#  'VALIANO PIZZA',
#  'WALLFLOWER',
#  'ZABLOZKIS',
#  'NIRVANA',
#  'RIVERWALK BAR & GRILL EXPRESS',
#  'TROPICAL BAR RESTAURANT',
#  'STARLETS',
#  'DOUGHNUTTERY',
#  'EXCELENTE GIL CAFETERIA & RESTAURANT',
#  'GREAT INDIAN CURRY',
#  'LA OAXAQUENA RESTAURANT',
#  "MARAVILLA'S BAR & GRILL",
#  'NATIVIDAD RESTAURANT',
#  'NELLO',
#  'RUSSIAN TURKISH BATHS',
#  'TACO KING',
#  '68 MEI MEI BAKERY',
#  'BOCCA',
#  'CARVEL ICE CREAM',
#  'DAZIES RESTAURANT',
#  'DUMPLINGS & THINGS',
#  "MCDONALD'S",
#  'MD KITCHEN',
#  'MINT MASALA',
#  'NIFOROS CORNER',
#  'OGAWA CAFE',
#  'RIBALTA',
#  'RICHMOND COUNTY COUNTRY CLUB - POOL SNACK BAR',
#  'THE STAND',
#  'EL PUNTO COLUMBIANO RESTAURANTE BAKERY',
#  'HAPPY COFFEE SHOP',
#  'MASAKI TERIYAKI & SUSHI',
#  'S & R LE JUICE BAR',
#  'SERAFINA GRILL',
#  'THE BEST OF NEW YORK FOOD',
#  'TROPHY',
#  "VINCENT'S PIZZERIA",
#  "WENG'S GARDEN",
#  'AMBROSINOS PIZZERIA',
#  'AUNT BUTCHIES/ REVIVE BAR',
#  "BARI'S PIZZA & PASTA RESTAURANT",
#  'BARILLA RESTAURANT',
#  'BG RESTAURANT',
#  'CELON BAR & LOUNGE',
#  'EL GUANACO RESTAURANT & PUPUSERIA',
#  "FLANAGAN'S TAVERN",
#  "FRANCESCO'S PIZZERIA RESTAURANT",
#  'MIRELI RESTAURANT',
#  'NEW ISLAND GARDEN',
#  'PICADILLY HALL',
#  'SUNDAES BY THE PARK',
#  'VERDI RESTAURANT',
#  'WORLD BEAN/VELOCITY BAR (EC2)',
#  'BOULEY BOTANICAL',
#  'HAPPINESS LOUNGE',
#  'LITTLE ITALY PIZZA/PAPAYA DOG',
#  "MAMMA LORNA'S RESTAURANT",
#  'TBA',
#  'VIVA',
#  'SHINJUKU',
#  'THE PATIO GRILL',
#  "BABY BO'S CANTINA",
#  "JIM BRADY'S RESTAURANT",
#  'MANGIA',
#  'AGORA TAVERNA',
#  'EASTERN CHINESE RESTAURANT',
#  'GOTTA GETTA BAGEL OF QUEENS',
#  'LA FAMILIA RESTAURANT',
#  'THE HOUSE IN GRAMERCY PARK',
#  'BIG APPLE CHINESE & JAPANESE RESTAURANT',
#  'CHEZ MA TANTE',
#  'CUCCIOS BAKERY',
#  "DIPPIN' DOTS",
#  "DIPPIN' DOTS (DINO DOTS)",
#  'EAST VILLAGE PIZZA AND KEBAB',
#  "PAPA JOHN'S",
#  'SUNDAE SHOP & SNACKS',
#  'TAQUERIA OAXACA',
#  'AU BON PAIN',
#  'BARKOGI',
#  'EURO PIZZA',
#  'GRK',
#  'INATESSO PIZZA BAR CASANO',
#  'MANDUCATIS RUSTICA VIG',
#  'MAYA TAQUERIA',
#  'OMEGA COFFEE SHOP',
#  'PLAY SPORTS BAR',
#  'POPEYES LOUISIANA KITCHEN',
#  'STADIUM PIZZA BAR RESTAURANT',
#  'SUNRISE MART',
#  "AUNT ANNIE'S",
#  'CAFE CENTRO',
#  'DREDSURFER GRILL',
#  'GINGERS (DOUBLE TREE HOTEL)',
#  'LEFT FIELD CONCESSION STAND',
#  'RIGHT FIELD BEER EXPRESS/PICNIC',
#  'SUITE KITCHEN',
#  'SUNSET PARK DINER & DONUTS',
#  'VILLA MARCELLO',
#  '1617-A NATIONAL BAKERY',
#  'A1 OCHA SUSHI',
#  'CONCESSION STAND 120',
#  'GOSSIPS',
#  'LEE LEE BUBBLE TEA',
#  "NEW DAVE'S",
#  "PIA'S PIZZERIA",
#  'STAND # 110',
#  'STAND #326',
#  'WIN HING CHINESE RESTAURANT',
#  'ARIA',
#  'INTREPID SEA-AIR-SPACE MUSEUM',
#  'RAIZES CHURRASCARIA',
#  'SKYVIEW DINER',
#  'YONG SHENG RESTAURANT',
#  'BLIND PIG',
#  'C. LO CAFE',
#  'GOLDEN CHINA PAVILION',
#  'LIBERTY RESTAURANT',
#  'PERA MEDITERRANEAN BRASSERIE',
#  'RIPPERS',
#  'YU KING BAKERY',
#  "CHUCK E. CHEESE'S",
#  'GARDENIA RESTAURANT',
#  'JEAN DANET FRENCH PASTRY',
#  'KNAPP PIZZA III',
#  'LOS 3 POTRILLOS',
#  'MANOR SUSHI',
#  'RMM LOUNGE',
#  'SING HUA KITCHEN',
#  'THE WEST SHORE INN RESTAURANT',
#  'EL TINA FISH MARKET & SEAFOOD RESTAURANT',
#  "GRINI'S GRILL & RESTAURANT",
#  'LEONIDAS',
#  'LULA BAGEL',
#  'ROSA MEXICANA',
#  'TASTE THE TROPICS ICE CREAM',
#  'HONEYBEE PATISSERIE',
#  'THE RIVER CAFE',
#  'LA LANTERNA DI VITTORIO',
#  'MARKET PLACE (CENTERPLATE)',
#  'METROPOLITAN MUSEUM ROOF TOP GARDEN CAFE',
#  'SALUD PERFECTA',
#  'BAMBOO TAVERN',
#  "BERGER'S ON THE GO",
#  'BIG DADDY CARIBBEAN TASTE',
#  'CAFE RIAZOR',
#  'DELICIOSO RESTAURANT',
#  'DOUBLE FIRE GOURMET',
#  'GENTE',
#  'LEON KITCHEN',
#  'MADISON & VINE',
#  'NY FRESH PIZZA',
#  'PURBIRD',
#  'ROW NYC/DISTRICT M',
#  'TEUTA QEBAPTORE',
#  'AL VICOLETTO',
#  'CAFFE VITA',
#  'CROMPTON ALE HOUSE',
#  'LE FATIMA BAR & GRILL',
#  'MOTHER PUGS SALOON',
#  "HUMRO BHIM'S CAFE,",
#  'BAR GOTO',
#  'BISTRO LES AMIS',
#  'BLACKSTONE  BAR AND GRILL',
#  'DOS TOROS',
#  'KAPPOCK CAFE',
#  'PARKER & QUINN',
#  'HOUSE OF ANTOJITOS',
#  "JOSEPH'S DREAM BURGER",
#  'KRISPY KREME',
#  'LUCKY HOUSE CHINESE KITCHEN',
#  "O'FLANAGAN'S",
#  "VANESSA'S DUMPLING HOUSE",
#  "CHOP'T",
#  'ELLINGTON IN THE PARK',
#  'JG Melon',
#  'LILY THAI RESTAURANT',
#  'OVERLOOK',
#  'PALADARES BAKERY & RESTAURANT',
#  'WEI MEI XIAN',
#  'GUARO DOMINICAN RESTAURANT',
#  'JAPAS 38',
#  'LJ PIZZA',
#  'NEUEHOUSE',
#  "WENDY'S",
#  "21 HOME'S KITCHEN",
#  'GOOD KITCHEN SEAFOOD RESTAURANT',
#  "GOODY'S BBQ",
#  'Imperial',
#  'LITUATION LOUNGE',
#  "NATHAN'S FAMOUS",
#  'BRUNO',
#  'DELI & GRILL',
#  'EL CAMION CANTINA',
#  'IVANA PIZZA',
#  'KAI FENG FU DUMPLING HOUSE',
#  'LOCK YARD',
#  "ORIGINAL NAPOLI'S PIZZA",
#  'PIG HEAVEN',
#  'WOOD AND ALES',
#  'Y CAFE',
#  'BISOUX MARKET/WORLD BEAN',
#  'BROOKLYN CAFE 1',
#  'DON PACO LOPEZ PANADERIA',
#  'HBO EDR',
#  'NO PARTNERS',
#  'OOTOYA',
#  'PRIME TAVERN/DELTA TERMINAL',
#  'TAGLIARE PIZZA  DELTA TERMINAL',
#  'WEST BANK CAFE',
#  'DELICIAS BAKERY',
#  'EDO SUSHI TERIYAKI NOODLE',
#  'GEN RESTAURANT',
#  'QUENTIN PIZZA',
#  'WRAP N ROLL',
#  'YI ZHANG FISHBALL',
#  'BATI',
#  'BEIT JEDDO',
#  'BEST WESTERN HOTEL HOSPITALITY HOUSE',
#  'COFFEE SHOP ON 8TH AVE',
#  'PERDITION',
#  'SOUTH SHORE SWIMMING CLUB',
#  'SUN IN BLOOM',
#  'BLUE FIN',
#  'OSTERIA AL DODGE',
#  "ZANNY'S CAFE",
#  'ZOMBIE HUT',
#  "CODY'S ALE HOUSE GRILL",
#  'FRUCES',
#  'GHANDI CAFE',
#  'LA BROCHETTE STEAKHOUSE.',
#  'SPICE GRILL',
#  "TASTY'S",
#  'TEMPURA MATSUI',
#  "DUNKIN' DONUTS/BASKIN ROBBINS",
#  'HAE WOON DAE RESTAURANT',
#  'LINDA ASIAN KITCHEN',
#  'MESKEREM',
#  "MICHAEL'S MEATBALLS & MARTINIS",
#  "BIG DADDY'S PIZZA",
#  'BRIK BAR LOUNGE & KITCHEN',
#  'BURGER KING',
#  'CIAO',
#  "DOMINO'S",
#  'EL-OMDA',
#  'EPISTROPHY CAFE',
#  'KAM TUNG RESTAURANT',
#  'MASPETH PIZZA',
#  'PAPA MIKES BRICK OVEN PIZZA',
#  'PIC UP STIX',
#  'PIZZA WAGON',
#  'RUINAS DE COPAN',
#  'THE MEATBALL SHOP',
#  'ALPHA BAKERY',
#  'COLONIA VERDE',
#  'GOLD STAR JERK CENTER',
#  'IVAN RAMEN',
#  'KANAN INDIAN RESTAURANT',
#  'LA GUALACENA BAR & RESTAURANT',
#  'MANHATTAN CENTER',
#  'MI PEQUENA CHOLULA DELI RESTAURANTE',
#  'NEW CHINA RESTAURANT',
#  "SAL'S DELI",
#  'TAQUERIA TLAXCALLI',
#  'TENDER TRAP',
#  'TERRA BLUES',
#  "THE BUTCHER'S DAUGHTER",
#  'WEST CUISINE-ENCHANTMENT BY MARIA',
#  'ALL NATIONS',
#  'BROOKLYN CUPCAKE',
#  'CAFE 58',
#  'ELSA LA REINA DEL CHICHARRON 3',
#  'GP SMOOTHIES & GIFTSHOP',
#  "HENRY'S END",
#  'SAFFRON',
#  'ISLAND CHOIZ RESTAURANT',
#  'BAI DAR CAFE',
#  'BROOKDALE',
#  'CASA MEXICANA',
#  'EASTERN RESTAURANT',
#  'ELI ZABAR',
#  'LE MONDE',
#  "MIGHTY QUINN'S BBQ",
#  'SUTTON CAFE RESTAURANT',
#  "XI'AN FAMOUS FOODS",
#  'AMATA',
#  'BLUEMAIZ',
#  'HEARTLAND BAGELS',
#  'K & D INTERNET CAFE',
#  'ODDFELLOWS ICE CREAM',
#  'SHIRO OF JAPAN',
#  'SOCCER TAVERN',
#  'AGNANTI RESTAURANT',
#  'BLACK SEED BAGELS',
#  'BY THE WAY BAKERY',
#  'KEENS STEAKHOUSE',
#  'KOSHER HUT OF BROOKLYN',
#  'LA ROSA BAKERY',
#  'MORGAN LIBRARY',
#  'PALM COURT',
#  'SANTA FE',
#  'VALHALLA',
#  'CAFE SAHARA',
#  'CHIRPING CHICKEN',
#  "FREDDY'S SOUL CARIBBEAN RESTAURANT CORP",
#  'QDOBA MEXICAN GRILL',
#  'THE MILLING ROOM',
#  'THE MONKEY ROOM',
#  'DAI HING GARDEN',
#  "FRIEDMAN'S",
#  'GIAN PIERO BAKERY',
#  'HYATT, NY CENTRAL, ROOM SERVICE',
#  'LA BAGUETTE SHOP',
#  'LIBERTY WAREHOUSE',
#  'NEW ASIAN CUISINE',
#  'PIER 79/NY WATERWAY SEATTLE CAFE',
#  'SL GREEN REALTY',
#  'TIAA-CREF CAFETERIA',
#  'NAZ BAKERY & ROTI SHOP',
#  'RESTAURANT TATIANA',
#  'WHEELERS',
#  'GRAND SLAM Banquet Hall',
#  'YAQUE RIVER',
#  '7 STARS RESTAURANT',
#  '888 KITCHEN',
#  'CHASERS',
#  'KAM MAN KITCHEN',
#  'NEW HOOD HING CHINESE RESTAURANT',
#  'TRIOMPHE',
#  'WAH YONG KITCHEN',
#  'CIRCLE IN THE SQUARE THEATRE',
#  'COME & GET SUM FISH & CHIPS',
#  'JADE LINDEN RESTAURANT',
#  'KARAOKE DUET 48',
#  'LA ISLA RESTAURANT',
#  'MI CASA BAKERY & COFFEE SHOP',
#  "MICHAEL ANGELO'S BRICK OVEN",
#  'RAYMI/LATIN BEET KITCHEN',
#  'SMASHBURGER',
#  'STUDIO 151',
#  'TRE',
#  '5 DE MAYO',
#  '5TH AVENUE ASIAN TASTE RESTAURANT',
#  'ASTORIA BAGEL SHOP',
#  'DON PICHON RESTAURANT',
#  'LEVAIN BAKERY',
#  'LUCKY EIGHT RESTAURANT',
#  'NIGHT LIGHT CAFE',
#  'OASIS CAFE',
#  'PEQUE VINOS + TAPAS',
#  'SPINCITY BILLIARD & CAFE',
#  'TASTE OF ITALY',
#  'THE RITZ-CARLTON PASTRY KITCHEN',
#  'UPRIGHT',
#  'CAFE EIGHTY TWO',
#  'CAFE1 & CAFE 4 (AMERICAN MUSEUM OF NATURAL HISTORY)',
#  'CROWN GRILL AND SALAD',
#  'EL CASTILLO DE JAGUA REST',
#  "HENRICA'S RESTAURANT",
#  'LAMARCA PASTA RESTAURANT',
#  "MOLLY'S",
#  'ONCE UPON A TART',
#  'TURQUOISE KOSHER FISH RESTAURANT',
#  'AFGAN KEBAB AND GRILL',
#  'HOUSING WORKS FOOD',
#  "JOHN MULLIGAN'S FIRESIDE PUB",
#  'PHAYUL RESTAURANT',
#  'SCALINATELLA RESTAURANT',
#  'THE CORNELL CENTER OF NEW YORK',
#  'BRUSHSTROKE (30 HUDSON ST)',
#  'IMPERIAL BAKERY',
#  "LUKE'S PIZZA",
#  "MAMA'S COOKING",
#  "MURPHY'S LAW",
#  'NEW SHENG CHINESE KITCHEN',
#  'PLANET WINGS',
#  'SAGAPONACK',
#  'TERIYAKI BURRITO HOUSE',
#  "AMERICAN HERO & SUB'S",
#  'AVE COFFEE HOUSE',
#  'BEDFORD FALLS',
#  "BRANDY'S PIANO BAR",
#  "CONNOLLY'S",
#  'EMPIRE CHINESE RESTAURANT ZHENG',
#  'ESCAPE INTERNATIONAL CUISINE',
#  'FUKU',
#  "JIM'S CHINA KING",
#  'MCDONALDS',
#  'MYUNG SAN RESTAURANT',
#  'RED LION INN & SUITES',
#  'TUSCANY CAFE',
#  'ULTIMATE BAKERY',
#  'ANYWAY CAFE',
#  'BAGEL CAFE',
#  'BROOKLYNS FINEST PIZZA & RESTAURANT',
#  'CAFE LOUP',
#  "CARRAGHER'S",
#  "DEILINE'S RESTAURANT",
#  "INSIDE PARK AT ST. BART'S",
#  'NEW JING HUI RESTAURANT',
#  'NOL BU FOOD',
#  'SHUNFA BAKERY',
#  'STRANGE LOVE BAR',
#  "TED'S MONTANA GRILL",
#  'BLUE PARROT BAR',
#  'CASABLANCA BAR & GRILL',
#  'EPICE CAFE',
#  'FRESH POND TAVERN',
#  'LINA RESTAURANT',
#  'LOVERAS LOUNGE',
#  'MR CAKE BAKERY & DESSERT',
#  'BRICK OVEN BREAD',
#  'GIMME COFFEE',
#  'MAMAJUANA CAFE / FIESTA CLUB',
#  'BAGELETTE',
#  'CLOCKTOWER',
#  'FRANKIES 570 SPUNTINO',
#  'MASAWA',
#  'MOSS CAFE',
#  'NATIONAL RESTAURANT & COFFEE SHOP',
#  'PAPA YE RESTAURANT',
#  'RIVERDALE SECOND HELPING',
#  'ALADDIN',
#  'AMSTERDAM BILLIARDS',
#  "GINO'S VILLA MONTE",
#  'KUU',
#  'LA MARINA',
#  'LA VILLA PIZZERIA',
#  'PRIME TIME CARIBBEAN BAKERY',
#  'THIRD RAIL COFFEE',
#  'WHISPERS BAR AND RESTAURANT',
#  'COLLEGE POINT MULTIPLEX CINEMAS',
#  'DALLAS BBQ',
#  "LIBRETTO'S PIZZERIA",
#  "MOJITO'S",
#  "RAY'S CANDY STORE",
#  'SHARMEL CATERERS',
#  'VIAND COFFEE SHOP',
#  'BROOK AVENUE DELI & PIZZA',
#  "COOGAN'S",
#  'CROCUS',
#  'HARMONY TERRACE',
#  "HO'BRAH",
#  "JACK'S SLIDERS AND SUSHI",
#  'KULU DESSERTS',
#  'LA NUEVA BAKERY',
#  'MAY LUCK KITCHEN',
#  'OM INDIAN RESTAURANT',
#  'POTBELLY SANDWICH WORKS',
#  'SMOKE',
#  'PATZERIA FAMILY & FRIENDS',
#  'SELAMAT PAGI',
#  'WOGIES BAR & GRILL',
#  '224TH CORNER RESTAURANT & BAKERY',
#  'DON PANCHOLO LECHONERA RESTAURANT',
#  'KEATS RESTAURANT',
#  "NEIR'S TAVERN",
#  "NICKOLAS' DELI RESTAURANT",
#  "PATSY'S PIZZERIA",
#  'PETER PAN DONUTS AND PASTRIES',
#  'THE KATI ROLL COMPANY',
#  'CAFE 1853',
#  'DAKE SUSHI',
#  'EDERLE TERRACE CAFE',
#  'FLORINDA RESTAURANT',
#  'FU LAI O KITCHEN',
#  'IMMACULEE BAKERY',
#  "JOSIE WOOD'S PUB",
#  "K'S CAFETERIA",
#  'THE CORNELIA STREET CAFE',
#  'WEST END HALL BEER GARDEN',
#  'BARBARESCO',
#  'CASA PROMESA',
#  'CHECKERS',
#  'EXTREME BLENDZ (CRUNCH)',
#  'GOURMET GARDEN 8',
#  'GREAT WALL CHINESE CUISINE',
#  "JAKE'S DILEMMA",
#  'JERUSALEM CAFE',
#  'LA SHUK',
#  'MIMI JAPANESE RESTAURANT',
#  'NEW THANKS GIVING CHINESE RESTAURANT',
#  'PINGS',
#  'PINO WINE BAR',
#  'POLPETTE 71',
#  'STAND # 210',
#  'THE BROOKLYN STRATEGIST',
#  'THE LEOPARD AT DES ARTISTES',
#  'THE SPOT CAFE/KOFOO',
#  "THREE BROTHER'S PIZZERIA",
#  'VANGUARD WINE BAR',
#  'YUMMY CHINESE RESTAURANT',
#  'CAFE & RESTAURANT BONGAR',
#  'CLAUDETTE',
#  "JOHNNY'S REEF RESTAURANT",
#  "LOJA'S PIZZA",
#  'MOLO',
#  'PETROSSIAN BOUTIQUE',
#  'THE SHAKESPEARE',
#  'BARCELONA BAR',
#  'FLAVA II',
#  "PEPPER'S CARIBBEAN RESTAURANT AND BAR",
#  'WESTVILLE',
#  'CAMPANIA COAL FIRED PIZZA',
#  'NOWADAYS',
#  'CARIBE RESTAURANT',
#  'CHINA WOK',
#  'DJ REYNOLDS PUB AND RESTAURANT',
#  'FORTUNE COOKIE',
#  'JONGRO BBQ',
#  'LEE XING RESTAURANT',
#  'LISSETT OMAR',
#  'MAGIC WOK',
#  'NUM PANG SANDWICH SHOP',
#  'RADIO STAR',
#  'TARTINERY',
#  'THE BEST ITALIAN PIZZA',
#  'USKUDAR RESTAURANT',
#  'V J  HOT BAGELS',
#  "BABY'S GRILL AND RESTAURANT",
#  'BLACK AND WHITE',
#  "BOB'S YOUR UNCLE",
#  "FRANK & DANNY'S PIZZERIA",
#  'GIUSEPPE PIZZERIA',
#  'JEEPNEY',
#  'LA BAGEL DELIGHT',
#  'OCEAN SIDE RESTAURANT',
#  "BARIO'S @ RICHMOND COUNTY SPORTS COMPLEX",
#  'CAPPUCCINO CAFE',
#  'COZZI PIZZA',
#  'GOUSTARO',
#  'SBARRO',
#  'THE LIGHTHOUSE',
#  "EVERYTHING YOGURT/GRETEL'S PRETZELS",
#  'MURASAKI SUSHI',
#  "NICKY'S JAMAICAN CUISINE",
#  'OAXACA GREENWICH',
#  'PIZZA HUT',
#  'RIVERDALE DINER',
#  'SODA BAR',
#  'TOPAZE RESTAURANT & JERK CHICKEN',
#  'TROPICAL PARADISE RESTAURANT & BAKERY',
#  "AUNTIE ANNE'S PRETZELS",
#  'CHINA GARDEN',
#  'CROWN FRIED CHICKEN',
#  'DRAFT BARN',
#  'INDIE FOOD AND WINE',
#  'LE VIET CAFE',
#  'MILLE-FEUILLE BAKERY',
#  "SCAVELLO'S ON THE ISLAND",
#  'UPSTAIRS LOUNGE THE KIMBERLY HOTEL/ BISTANGO',
#  'GREENPOINT BEER & ALE',
#  'AUSTIN HOUSE',
#  "BEN & JERRY'S",
#  'CARIDAD',
#  'CHEF YU / AZUKI',
#  'IL CORALLO',
#  'JALAPENO DELI',
#  'KOBEYAKI',
#  'KUM WEI KITCHEN',
#  'LEGEND',
#  'LITTLE CAESARS',
#  'LONG ISLAND UNIVERSITY - BLACKBIRD CAFE',
#  'MARINA GOURMET DELI.',
#  'NEW CHINA DELIGHT',
#  "O'BRIENS",
#  "PADDY MAGUIRE'S ALE HOUSE",
#  'THE LEXINGTON SOCIAL',
#  'U CAFE',
#  "WIMPY'S RESTAURANT",
#  'BESO RESTAURANT AND BAR',
#  'BLOCKHEADS',
#  'BOCCA DI BACCO',
#  'BUFFALO WILD WINGS',
#  'GOLDEN WOKS',
#  'GRANDCHAMPS',
#  'IL BAMBINO',
#  'LA TARTE FLAMBEE',
#  'MACCHINA NYC',
#  'OVENLY',
#  "PATRICIA'S",
#  "ROBERTA'S PIZZA",
#  'SANFORDS RESTAURANT',
#  "SARGE'S",
#  'SCAGLIONE BROTHERS BAKERY',
#  'TAKUMI TACO',
#  "VINNY'S LUNCHBOX",
#  'WILD GINGER VEGETARIAN KITCHEN',
#  'ANNA MARIA PIZZA PASTA',
#  'BELLA PIZZA & RESTAURANT',
#  'BK JANI',
#  'CROISSANTERIA',
#  'DON PANCHO VILLA RESTAURANT',
#  'GOOD TASTE #1',
#  'HAVELI FINE INDIAN CUISINE',
#  'HOT KITCHEN SICHUAN STYLE',
#  'LA BELLA MARIELLA',
#  'LUPITA RESTAURANT',
#  'Le Bernardin Priv̩/Wine Bar',
#  'MACARON',
#  'MEI YA KITCHEN',
#  'MORNINGSTAR RESTAURANT',
#  'NIGHT MARKET BBQ',
#  'SILHOUETTE RESTAURANT LOUNGE',
#  'TRA DI NOI',
#  'XIN LI',
#  'BEMBE',
#  'BRAVO PIZZA',
#  'CITIGROUP CONFERENCE DINING',
#  'PYE BOAT NOODLE',
#  'STUDIO 299',
#  'VISTA SKY LOUNGE & CATERING (SHERATON FOUR POINTS)',
#  'WO HOP 17',
#  'CHEN WON DIM SUM & BAKERY',
#  "NORA'S PARK BENCH CAFE",
#  'QUEEN SHEEBA RESTAURANT',
#  'AZUKI',
#  'CAFFE NOI ESPRESSO BAR',
#  'CAKOR RESTAURANT',
#  'COCO FRESH TEA & JUICE',
#  'EASY CORNER RESTAURANT & GRILL',
#  'FUSION EAST',
#  'GONG CHA',
#  'HAPPY GARDEN',
#  'HUA HUI BAKERY',
#  'MARUZZELLA',
#  'MAZI NIGHTCLUB',
#  'MEX CARROLL DINER',
#  'NICK GARDEN COFFEE SHOP',
#  'PEACHES JAMAICAN RESTAURANT',
#  'PICASSO PIZZERIA',
#  "SAC'S PIZZA PLACE",
#  'WOORIJIP',
#  'ZEREGA AVENUE DELI',
#  'ALITALIA MICHELANGELO LOUNGE',
#  'AMALI MOU',
#  'BANN',
#  "BLOCKHEAD'S MEXICAN DINER",
#  'CASCABEL TAQUERIA',
#  'DREAM PIZZA',
#  'HALE & HEARTY SOUP',
#  'HOURGLASS TAVERN',
#  'IL TINELLO RISTORANTE',
#  'JUN-MEN RAMEN BAR',
#  'PZA',
#  "RUDY'S DELI RESTAURANT",
#  'RUSSIAN SAMOVAR',
#  'ABC KITCHEN',
#  'BOSTON MARKET',
#  "CHARLEY'S GRILLED SUBS",
#  'COMMONWEALTH',
#  'EL CAFETAL',
#  'EL LEMPIRAS RESTAURANT',
#  'HARD ROCK CAFE',
#  'HUNTS POINT JUICE BAR & DELI',
#  'JING XIN CHINESE FOOD TAKE OUT',
#  'LA CUESTA',
#  "NEW PEPERONI'S PIZZA",
#  'PARSONS ALE HOUSE',
#  'THE MILL COFFEE HOUSE',
#  'TU CACHAPA',
#  'YOLANDA PIZZERIA RESTAURANT',
#  'AMF BOWLING CENTER',
#  'BASSO56',
#  'FORDHAM FRIED CHICKEN & SEA FOOD',
#  'GALLERIES LOUNGE BRITISH AIRWAYS',
#  'GRAND BANKS',
#  'GREEN LOTUS',
#  'JOE ALLEN RESTAURANT',
#  'LIU WRAC WELLNESS CENTER',
#  "LORETTA'S PIZZA",
#  'MAMAJUANA CAFE',
#  'MBJ SOUTH (NAMM CAFE)',
#  "PATSY'S PIZZERIA RESTAURANT",
#  'PICCOLO ANGOLO',
#  "ADELINA'S",
#  'CAFE PANINO MUCHO GUSTO',
#  'CASANOVA RESTAURANT',
#  'JAMAICAN FLAVORS',
#  'NEW MILLENIUM PIZZERIA',
#  "SYLVIA'S RESTAURANT",
#  'THE FINANCIER PATISSERIE',
#  'THE HAROLD',
#  'THE RED DOORS BAR AND GRILL',
#  'TRI-COLOR RESTAURANT AND PIZZERIA',
#  "SAL'S PIZZERIA",
#  'TAQUERIA LA PLACITA PUEBLA',
#  'TOMMY THAI',
#  'ARABELLE',
#  'BLACKSTAR BAKERY CAFE',
#  'DOJO RESTAURANT',
#  'IRVING FARM',
#  ...]

# %%
chain = store_num.loc[store_num['camis_count'] > 10]
chain_rank = chain.groupby(['dba'])['camis_count'].sum().reset_index().sort_values(['camis_count'],ascending=False)
print(len(list(chain_rank['dba'].unique())))
chain_list = list(chain_rank['dba'].unique())[:10]
chain_rank.head(10)
# Out:
# 172
#                                        dba  camis_count
# 42                          DUNKIN' DONUTS         1128
# 144                                 SUBWAY          576
# 143                              STARBUCKS          286
# 95                              MCDONALD'S          155
# 76                   KENNEDY FRIED CHICKEN          103
# 40                                DOMINO'S           94
# 32                     CROWN FRIED CHICKEN           61
# 54   GOLDEN KRUST CARIBBEAN BAKERY & GRILL           59
# 43          DUNKIN' DONUTS, BASKIN ROBBINS           36
# 151                          THE AINSWORTH           27

# %%
store_count = store_num.groupby(['inspection_year','dba'])['camis_count'].sum().reset_index()
store_count = store_count.pivot(index='inspection_year',columns='dba',values='camis_count').fillna(0)
chain = store_count[chain_list]
chain.head()
# Out:
# dba              DUNKIN' DONUTS  SUBWAY  STARBUCKS  MCDONALD'S  \
# inspection_year
# 2015                      213.0    65.0       61.0        88.0
# 2016                      883.0   628.0      415.0       525.0
# 2017                     1255.0   767.0      645.0       573.0
# 2018                     1379.0  1054.0      688.0       571.0
# 2019                      536.0   467.0      291.0       302.0
#
# dba              KENNEDY FRIED CHICKEN  DOMINO'S  CROWN FRIED CHICKEN  \
# inspection_year
# 2015                              35.0      59.0                  9.0
# 2016                             238.0     265.0                154.0
# 2017                             269.0     322.0                211.0
# 2018                             476.0     281.0                438.0
# 2019                             253.0     118.0                148.0
#
# dba              GOLDEN KRUST CARIBBEAN BAKERY & GRILL  \
# inspection_year
# 2015                                              29.0
# 2016                                             193.0
# 2017                                             233.0
# 2018                                             297.0
# 2019                                             100.0
#
# dba              DUNKIN' DONUTS, BASKIN ROBBINS  THE AINSWORTH
# inspection_year
# 2015                                       66.0            0.0
# 2016                                      226.0           22.0
# 2017                                      364.0           14.0
# 2018                                      308.0           52.0
# 2019                                      143.0           25.0

# %%
cds_chain = ColumnDataSource(chain)
cds_chain.column_names
# Out:
# ['inspection_year',
#  "DUNKIN' DONUTS",
#  'SUBWAY',
#  'STARBUCKS',
#  "MCDONALD'S",
#  'KENNEDY FRIED CHICKEN',
#  "DOMINO'S",
#  'CROWN FRIED CHICKEN',
#  'GOLDEN KRUST CARIBBEAN BAKERY & GRILL',
#  "DUNKIN' DONUTS, BASKIN ROBBINS",
#  'THE AINSWORTH']

# %%
chart = figure(height = 1000, width = 1000,
               title = "Number of Locations",
               x_axis_type = "linear",
               tools = "pan,wheel_zoom,box_zoom,reset,save,zoom_in,zoom_out,lasso_select")

# %%
line_list = list(cds_chain.column_names)[1:10]
line_color = ['#a6cee3','#1f78b4','#b2df8a','#33a02c',
              '#fb9a99','#e31a1c','#fdbf6f','#ff7f00',
              '#cab2d6','#6a3d9a','#ffff99','#b15928',
              '#000000','#8dd3c7','#ffffb3','#bebada','#fb8072',
              '#80b1d3','#fdb462','#b3de69','#fccde5',
              '#d9d9d9','#bc80bd','#ccebc5','#ffed6f']
#if "inspection_date" in line_list: 
 #   line_list.remove("inspection_date")
print(len(line_list))
print(len(line_color))
print(line_list)
# Out:
# 9
# 25
# ["DUNKIN' DONUTS", 'SUBWAY', 'STARBUCKS', "MCDONALD'S", 'KENNEDY FRIED CHICKEN', "DOMINO'S", 'CROWN FRIED CHICKEN', 'GOLDEN KRUST CARIBBEAN BAKERY & GRILL', "DUNKIN' DONUTS, BASKIN ROBBINS"]

# %%
for i in range(len(line_list)):
    chart.line(x = "inspection_year", y = line_list[i], color = line_color[i], 
               legend = value(line_list[i]), source = cds_chain)
chart.legend.click_policy = "hide"
chart.legend.location = 'top_left'
output_file('chain_line.html')
show(chart)
# Out:
#   <div class="bk-root" id="311e803c-7157-48d5-b032-8d28da7d6344"></div>

# %% [markdown]
# # 2. Checkbox and Line Chart

# %%
boro = pd.read_csv('boro_tidy.csv')
boro = boro.loc[boro['inspection_year'] >= 2015]
boro = boro.loc[boro['dba'].isin(chain_list)]
boro.head()
# Out:
#      Unnamed: 0   boro  inspection_year  \
# 56           56  BRONX             2015
# 57           57  BRONX             2015
# 58           58  BRONX             2015
# 78           78  BRONX             2015
# 104         104  BRONX             2015
#
#                                        dba grade  camis_count
# 56                          DUNKIN' DONUTS     A           21
# 57                          DUNKIN' DONUTS     C            4
# 58          DUNKIN' DONUTS, BASKIN ROBBINS     A            2
# 78   GOLDEN KRUST CARIBBEAN BAKERY & GRILL     A            3
# 104                  KENNEDY FRIED CHICKEN     A           10

# %%
boro_group = boro.groupby(['inspection_year','boro','dba','grade'])['camis_count'].sum().reset_index()
boro_list = list(boro_group['boro'].unique())
store_list = list(boro_group['dba'].unique())
grade_list = list(boro_group['grade'].unique())
boro_list
store_list
grade_list
# Out:
# ['A', 'C', 'B', 'P', 'Not Yet Graded', 'Z']

# %%
boro_group.head()
# Out:
#    inspection_year   boro                                    dba grade  \
# 0             2015  BRONX                         DUNKIN' DONUTS     A
# 1             2015  BRONX                         DUNKIN' DONUTS     C
# 2             2015  BRONX         DUNKIN' DONUTS, BASKIN ROBBINS     A
# 3             2015  BRONX  GOLDEN KRUST CARIBBEAN BAKERY & GRILL     A
# 4             2015  BRONX                  KENNEDY FRIED CHICKEN     A
#
#    camis_count
# 0           21
# 1            4
# 2            2
# 3            3
# 4           10

# %%
def adjust_df(chain_list):
    boro = boro_group.copy()
    for i, chain_name in enumerate(chain_list):
        each_chain = boro[boro['dba'] == chain_name]

# %%
def update(attr, old, new):
    # Get the list of restaurants for the graph
    boros_to_plot = store_list.labels

    # Make a new dataset based on the selected carriers and the 
    # make_dataset function defined earlier
    new_src = make_dataset(carriers_to_plot,
                           range_start = -60,
                           range_end = 120,
                           bin_width = 5)
    
    # Convert dataframe to column data source
    new_src = ColumnDataSource(new_src)

    # Update the source used the quad glpyhs
    src.data.update(new_src.data)

# %%
for i, a in enumerate(boro_list):
    print(f'i:{i},a:{a}')
# Out:
# i:0,a:BRONX
# i:1,a:BROOKLYN
# i:2,a:MANHATTAN
# i:3,a:QUEENS
# i:4,a:STATEN ISLAND
