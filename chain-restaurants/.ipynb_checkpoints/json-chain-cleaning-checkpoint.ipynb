# %% [markdown]
# # NYC Chain Restaurant Inspection Results

# %%
import pandas as pd
from sodapy import Socrata
from config import API_Key, username, password
import requests
import json
import matplotlib.pyplot as plt
import re, datetime

from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.io import show, output_notebook
from bokeh.transform import dodge
from bokeh.core.properties import value
from bokeh.palettes import Spectral6

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 1. Loading Data from API

# %%
# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us", API_Key, username, password)

# Returned as JSON from API by sodapy.
data = client.get("43nn-pn8j",limit=381912)

# Convert to pandas DataFrame
data_df = pd.DataFrame.from_records(data)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381912 entries, 0 to 381911
# Data columns (total 18 columns):
# action                   381438 non-null object
# boro                     381912 non-null object
# building                 381691 non-null object
# camis                    381912 non-null object
# critical_flag            381912 non-null object
# cuisine_description      381912 non-null object
# dba                      381794 non-null object
# grade                    192482 non-null object
# grade_date               190650 non-null object
# inspection_date          381912 non-null object
# inspection_type          381438 non-null object
# phone                    381894 non-null object
# record_date              381912 non-null object
# score                    364711 non-null object
# street                   381912 non-null object
# violation_code           376981 non-null object
# violation_description    374214 non-null object
# zipcode                  376398 non-null object
# dtypes: object(18)
# memory usage: 52.4+ MB

# %%
data_df = data_df.replace({"PAPA JOHN'S PIZZA":"PAPA JOHN'S",
                           "DUNKIN DONUTS":"DUNKIN' DONUTS"})
data_df['inspection_year'] = data_df['inspection_date'].apply(lambda x: datetime.datetime.strptime(x,'%Y-%m-%dT%H:%M:%S.%f').year)

# %%
data_df['inspection_year'].unique()
# Out:
# array([2018, 2017, 2016, 2019, 2015, 2014, 2013, 2012, 2011, 1900],
#       dtype=int64)

# %% [markdown]
# ## 2. Chain Restaurants by Year and Boroughs
# - Create a function `make_df` to create dataframes for analysis
# - Group all non-chain restaurants into groups

# %%
# A copy of data_df is to take in all the data manipulation
# Original data_df is reserved to be used again

stores = data_df.copy()

# %%
# data = dataset
# value_col = columns to be aggregated
# index_col = columns to be grouped by

def make_df(data, value_col, index_col=['boro','dba']):
    df = data.groupby(index_col)[value_col].count().reset_index()
    df = pd.DataFrame(df)
    for value in value_col:
        df = df.rename(columns = {value:f'{value}_count'})
    return df

# %%
store_num = make_df(data_df, ['camis'], index_col=['inspection_date','inspection_year','dba'])
store_num = store_num.loc[store_num['inspection_year'] >= 2015]

local = store_num.loc[store_num['camis_count'] <= 100]
print(len(list(local['dba'].unique())))
local_list = list(local['dba'].unique())
local_list
# Out:
# 20545
# ['RELISH CONCESSIONS (LASKER RINK)',
#  'DELMY FOOD',
#  'EL PATRON NIGHTCLUB CABARET-RESTAURANT',
#  'VILLA BARONE',
#  'OLYMPIC PIER CAFE',
#  'HUNAN GLATT KOSHER',
#  'SORRENTINE',
#  '4O KNOTS',
#  "CLAUDINE'S",
#  'GRAND OASIS RESTAURANT',
#  'BAR NONE',
#  'MERRY LAND BUFFET',
#  'BROOKLYN SWEET SPOT',
#  'TERTULIA',
#  'PORTALIA RISTORANTE BAR AND LOUNGE',
#  'RICHMOND COUNTY COUNTRY CLUB',
#  'THEATER CAFE',
#  'NEW POLODOS LOUNGE',
#  'NOVITA',
#  "GIACOMO'S WOOD FIRED PIZZA",
#  "Pinot's Pallette",
#  'SABOR NORTENO',
#  'RICHMOND COUNTY YACHT CLUB',
#  'DESNUDA',
#  'TREADWELL PARK / BLACK HOUND',
#  'ROSSVILLE PIZZERIA',
#  'THE FINCH',
#  'BEST WESTERN PREMIER HERALD SQUARE',
#  "STEINBERG CENTER THEATER(JODI'S LOUNGE)",
#  "GUSSY'S BAR",
#  'FALAFEL OFF THE CORNER',
#  'KNIGHTS OF COLUMBUS HOUSE',
#  'SHAARE ZION CATERERS',
#  'HUDSON BAR AND BOOKS',
#  'HECHO EN DUMBO',
#  'PHILIPPE NYC I',
#  'ROYAL RIB HOUSE',
#  'POK POK NY',
#  'JULIUS',
#  'LE COLONIAL',
#  'VAN LEEUWEN ARTISAN ICE CREAM',
#  'GINA MEXICANA',
#  'MIX',
#  'AGUA ROJA BAR & LOUNGE',
#  'ATWOOD KITCHEN & BAR',
#  'DAVIS FAMILY ESTABLISHMENT',
#  'BLEND',
#  'GREENPOINT TAVERN',
#  'MAISON MAY',
#  'THE BLUE GOOSE',
#  'CAFE DUKE',
#  'NEW YORK UNIVERSITY - PALLADIUM FOOD COURT',
#  "NICKY'S PIZZA",
#  'TROPICAL 128',
#  'WEST 3RD COMMON',
#  "DANIELA'S CAFE",
#  'TEVERE 84',
#  'FAT BUDDHA',
#  'THE SUPPLY HOUSE',
#  'EL PARAISO LOUNGE',
#  'ESME',
#  "LOVELL'S GUIDING LIGHT",
#  'NEW PHOENIX PALACE',
#  'HAN DYNASTY',
#  'LA SORRENTINA RISTORANTE',
#  'MEMBERS DINING ROOM @ THE MET MUSEUM',
#  'MIYAKO SUSHI',
#  'RINGOLEVIO',
#  'THE PAPER BOX',
#  'YANKEE CLIPPER',
#  'EUROS EL TINA RESTAURANT LOUNGE AND BILLIARDS',
#  'PRONTO PIZZA',
#  'KYO-YA',
#  'MAMAN & MIMI NOLITA',
#  'SUZAN KITCHEN',
#  'FOOD KING',
#  'LAVAZZA ESPRESSO BAR',
#  'OUTPUT CLUB',
#  'PILAR CUBAN EATERY',
#  'STARBUCKS',
#  'VIN SUR VINGT',
#  'BAR GREAT HARRY',
#  'DINOSAUR BAR-B-QUE',
#  "LEO'S DELI & GRILL",
#  'PAPA RESTAURANT',
#  'CIRCLE LINE BROOKLYN',
#  'KABAB CAFE',
#  "MUG-Z'S SPORTS BAR",
#  'SOFITEL NEW YORK',
#  'SPICE',
#  'THE BOMOND RESTAURANT',
#  'THE SMITH',
#  'AMC THEATRES',
#  "ARTURO'S",
#  'SECRETS',
#  'MAOZ VEGETARIAN',
#  'THE WOODS/ THE BEAR (BACKYARD)',
#  'TUFFET',
#  'VINTAGE CURRY',
#  'CARROLL PLACE',
#  'EL QUIJOTE',
#  "JUICY LUCY'S",
#  'SWEDISH FOOTBALL CLUB',
#  'EL PORTON BAR & RESTAURANT',
#  'HARMONIE CLUB',
#  'The Big Whiskey',
#  'UNFORGETTABLE LOUNGE',
#  'BAKU PALACE',
#  'CANTINA ROYAL',
#  'SPORTS LUNCHEONETTE',
#  'TAVERN ON THE GREEN',
#  'THE COUNTING ROOM',
#  'THE RUSSIAN TEA ROOM',
#  'THE SIMONE',
#  'THE TANGLED VINE',
#  'PARK AVENUE LUNCHEONETTE',
#  'BLARNEY CASTLE',
#  "DUNKIN' DONUTS",
#  'STILLWATER BAR & GRILL',
#  'THE CLAM',
#  'DA NICO RESTAURANT',
#  'DUE PONTI RISTORANTE ITALIANO',
#  "JOSIE'S BAR",
#  'MERMAID SPORTS BAR',
#  'RATTLE N HUM',
#  "STAN'S SPORTS BAR",
#  'STK',
#  'DJ PIZZA',
#  'KI SUSHI',
#  'OMIYA SUSHI II',
#  'PICCOLI TRATTORIA',
#  'BATEAUX NEW YORK',
#  'DOYLES PUB',
#  'EAST DIM SUM',
#  'LATERNA TAVERNA',
#  'POTJANEE',
#  'VIDA',
#  'DEJA VU LOUNGE & BAR',
#  'FISH BAR',
#  'GOTHAM PIZZA',
#  'NEW PINANG',
#  'BANGAGAN',
#  'BROOKLYN BOWL',
#  'IVY',
#  'LTK LITTLE THAI KITCHEN',
#  'ROEBLING PIZZA',
#  "E'S BAR",
#  'EASTWOOD MANOR',
#  "MARCELLA'S PIZZERIA & CATERING",
#  "NEW EVERYBODY'S KITCHEN",
#  'WILFIE & NELL',
#  'BAREBURGER',
#  'CAFE LATTE',
#  'LOIS BAR',
#  'MAGNA BAR & RESTAURANT',
#  'BURNSIDE BEER & WINE CAFETERIA',
#  'CAPIZZI',
#  'ROSEBANK TAVERN',
#  'CHEN XIN LUNG CHINESE RESTAURANT',
#  'GOLDEN KRUST CARIBBEAN BAKERY & GRILL',
#  'KNICKERBOCKER CLUB',
#  'MAYFIELD',
#  'NANO',
#  'STARZ BANQUET HALL',
#  'TREE',
#  "VIRGINIA'S",
#  'MELROSE BALLROOM',
#  'SALSA CON FUEGO',
#  'BAMBOO TROPICAL',
#  'DE ISLANDS',
#  'EAGLE CITY TEX MEX CHINESE FOOD',
#  'HONG BAO RESTAURANT',
#  'JUICE AMMIEL',
#  'LA CARBORNARA',
#  'NEW PEKING',
#  "NINA'S RESTAURANT PIZZERIA",
#  'SOCIALE',
#  'SUMA SUSHI',
#  'SUSHI CHOSI',
#  'SUSHI KOI',
#  "BROTHER JIMMY'S BBQ",
#  "DUNKIN' DONUTS, BASKIN ROBBINS",
#  'FAT GOOSE',
#  'GARI',
#  'NITEHAWK CINEMA',
#  'SUNITA',
#  'BEST PIZZA ON 1ST.',
#  'ESTIATORIO MILOS',
#  'FORTY EIGHT LOUNGE',
#  'FULTON CAFE',
#  'INASE SUSHI RESTAURANT',
#  'KETTLE OF FISH',
#  'Kurant',
#  'LITTLE SKIPS',
#  'PROJECT PARLOR',
#  'RAMONA',
#  'cloud social',
#  'BAYRIDGE PIZZA',
#  'BUTTERMILK CHANNEL',
#  "DEACON BRODIE'S",
#  'EAT-A-BAGEL - BOAT SPIRIT OF AMERICA',
#  'HABANERO CAFE MEXICAN GRILL',
#  'JUST MADE SUSHI (DD MARU)',
#  "KATHY'S GOURMET ITALIAN ICES & ICE CREAM",
#  'LE GIGOT',
#  'MAITE',
#  'NEW DYNASTY',
#  'NEW FOOD KING',
#  'SHAKE SHACK',
#  'SPUYTEN DUYVIL',
#  'SWAY LOUNGE',
#  'ZAMAAN HOOKAH BAR',
#  'B.A.M. CAFE/GREAT PERFORMANCES',
#  'CAPRICE',
#  'CHIAN FEDERATION',
#  "DUNKIN' DONUTS/ BASKIN ROBBINS",
#  'GUYANA EX POLICE ASSOCIATION OF AMERICA',
#  'IMPERIAL THEATRE',
#  'LA FONDA DEL SOL',
#  'LOLLIPOPS ICE CREAM',
#  'POLISH NATIONAL HOME',
#  'TANDOOR PALACE',
#  'CB CHARISMA BALLROOM',
#  "FOXY GENTLEMEN'S CLUB",
#  'THE WAY STATION',
#  'BLUE RIBBON SUSHI',
#  'CAFE METRO',
#  'LITTLE ITALY M & O PIZZA RESTAURANT',
#  'MI CASITA RESTARANT',
#  'PRET A MANGER',
#  'SPIRIT OF NEW JERSEY',
#  'WATAWA JAPANESE RESTAURANT',
#  'WORLD YACHT - ST. CHARLES',
#  'BARNES & NOBLE CAFE',
#  'CAFE PARIS',
#  'CHOP CHOP KITCHEN',
#  'CIROS PASTRY SHOP',
#  'CUCINA FRESCA',
#  'ELEGANTE PASTRY SHOP',
#  "Lenny's",
#  'MAX  CAFFE',
#  "O'DONOGHUE'S",
#  'RICE TO RICHES',
#  'THE HARP',
#  'BARIOS PIZZA & RESTAURANT',
#  'EL CARIBE',
#  'EMPIRE TORTILLAS',
#  'EMPORIO',
#  'El Pollo II Restaurant',
#  'HAPPY FUN HIDEAWAY',
#  "HUNAN ''K'' CHINESE RESTAURANT",
#  'NOREETUH',
#  'SERVICE BAR 5',
#  'SKY TERRACE BAR',
#  'SPIRIT OF NEW YORK',
#  'SUBWAY',
#  'THE MOONLIGHTMILE',
#  'COBBLE HILL CINEMAS',
#  'EL PITALLITO RESTAURANT',
#  'LA GITANA PANADERIA - RESTAURANTE',
#  'LITTLE CAESARS',
#  'THE BAGEL FACTORY',
#  'THE WAVERLY INN',
#  'TRANQUILITY BAR & LOUNGE',
#  'YUMMY HOUSE',
#  'BEST WESTERN CONVENTION CENTER',
#  'BUTTERFIELD CATERING',
#  'GEORGES RESTAURANT',
#  "LENNY'S BAGELS",
#  "NAIDRE'S",
#  'THE SHANTY',
#  'VALBONA RESTAURANT',
#  'VERO',
#  'GASTROTECA ASTORIA',
#  'INDO CHINE',
#  'PEQUENA',
#  'SARILING ATIN',
#  'SHUBERT THEATER',
#  'WEST END BAR & GRILL',
#  'YO-YO FRITAILLE',
#  'DRUNKEN HORSE',
#  'GRAND CAFE (Metropolitan Hospital)',
#  'GREENPOINT DELI',
#  'HABANA OUTPOST',
#  "LUCY'S VIETNAMESE KITCHEN",
#  'MARINA CAFE',
#  'SOUTH SHORE LITTLE LEAGUE CONCESION STAND',
#  'THE GREEK KITCHEN  CLINTON BAKERY CAFE',
#  "THOMASINA'S CATERING HALL",
#  'BURGER KING',
#  'FORNINO',
#  'LOUNGE BAR CAVE',
#  'STATEN ISLAND 16 THEATRE',
#  'TAAM MEVORACH',
#  'THE ONENESS FOUNTAIN HEART',
#  'AL HORNO LEAN MEXICAN KITCHEN INC',
#  'BOWLER LAND',
#  'CAFE ARTE',
#  'METRO STAR COFFEE SHOP',
#  'MY KITCHEN',
#  'PIER 60',
#  'MACE',
#  'PAULIE GEE',
#  'PELHAM BAY DINER',
#  'CHIPOTLE MEXICAN GRILL',
#  'HERO CHAMP',
#  'ISLAND RAGE',
#  'PRANZO',
#  'CHINA PAGODA',
#  'JADE PALACE',
#  'MID CHINA',
#  'MIN JIANG MINI CAFE',
#  'RANDOLPH BEER',
#  "GINO'S PIZZA EXPRESS",
#  'Great Wall',
#  'HARD TIMES',
#  'KINFOLK',
#  'KNIGHTS OF BARON DEKALB',
#  'KORALI ESTIATORIO',
#  'PIECES',
#  'ROCKWAY BEACH CLUB',
#  "SHASHEMENE INT'L RESTAURANT",
#  'TAGLIERE',
#  'BALLFIELDS CAFE',
#  'CIAO FOR NOW',
#  'CUBBYHOLE',
#  'GOMI-WINE-FOOD-FRIENDS',
#  'PRABHU KIRPA SWEETS AND RESTAURANT',
#  'SIENA',
#  'SWEET EXPRESSIONS',
#  'VALIANO PIZZA',
#  'WALLFLOWER',
#  'ZABLOZKIS',
#  'NIRVANA',
#  'RIVERWALK BAR & GRILL EXPRESS',
#  'TROPICAL BAR RESTAURANT',
#  'STARLETS',
#  'DOUGHNUTTERY',
#  'EXCELENTE GIL CAFETERIA & RESTAURANT',
#  'GREAT INDIAN CURRY',
#  'LA OAXAQUENA RESTAURANT',
#  "MARAVILLA'S BAR & GRILL",
#  'NATIVIDAD RESTAURANT',
#  'NELLO',
#  'RUSSIAN TURKISH BATHS',
#  'TACO KING',
#  '68 MEI MEI BAKERY',
#  'BOCCA',
#  'CARVEL ICE CREAM',
#  'DAZIES RESTAURANT',
#  'DUMPLINGS & THINGS',
#  "MCDONALD'S",
#  'MD KITCHEN',
#  'MINT MASALA',
#  'NIFOROS CORNER',
#  'OGAWA CAFE',
#  'RIBALTA',
#  'RICHMOND COUNTY COUNTRY CLUB - POOL SNACK BAR',
#  'THE STAND',
#  'COWGIRL SEAHORSE',
#  'EL PUNTO COLUMBIANO RESTAURANTE BAKERY',
#  'HAPPY COFFEE SHOP',
#  'MASAKI TERIYAKI & SUSHI',
#  'S & R LE JUICE BAR',
#  'SERAFINA GRILL',
#  'THE BEST OF NEW YORK FOOD',
#  'TROPHY',
#  "VINCENT'S PIZZERIA",
#  "WENG'S GARDEN",
#  'AMBROSINOS PIZZERIA',
#  'AUNT BUTCHIES/ REVIVE BAR',
#  "BARI'S PIZZA & PASTA RESTAURANT",
#  'BARILLA RESTAURANT',
#  'BG RESTAURANT',
#  'CELON BAR & LOUNGE',
#  'EL GUANACO RESTAURANT & PUPUSERIA',
#  "FLANAGAN'S TAVERN",
#  "FRANCESCO'S PIZZERIA RESTAURANT",
#  'MIRELI RESTAURANT',
#  'NEW ISLAND GARDEN',
#  'PICADILLY HALL',
#  'SUNDAES BY THE PARK',
#  'VERDI RESTAURANT',
#  'WORLD BEAN/VELOCITY BAR (EC2)',
#  'BOULEY BOTANICAL',
#  'HAPPINESS LOUNGE',
#  'IG NIGHT',
#  'LITTLE ITALY PIZZA/PAPAYA DOG',
#  "MAMMA LORNA'S RESTAURANT",
#  'TBA',
#  "VICKY'S DINER",
#  'VIVA',
#  'SHINJUKU',
#  'THE PATIO GRILL',
#  "BABY BO'S CANTINA",
#  "JIM BRADY'S RESTAURANT",
#  'MANGIA',
#  'AGORA TAVERNA',
#  'EASTERN CHINESE RESTAURANT',
#  'GOTTA GETTA BAGEL OF QUEENS',
#  'LA FAMILIA RESTAURANT',
#  'THE HOUSE IN GRAMERCY PARK',
#  'BIG APPLE CHINESE & JAPANESE RESTAURANT',
#  'CHEZ MA TANTE',
#  'CUCCIOS BAKERY',
#  "DIPPIN' DOTS",
#  "DIPPIN' DOTS (DINO DOTS)",
#  'EAST VILLAGE PIZZA AND KEBAB',
#  'KENNEDY FRIED CHICKEN',
#  "PAPA JOHN'S",
#  'SUNDAE SHOP & SNACKS',
#  'TAQUERIA OAXACA',
#  'AU BON PAIN',
#  'BARKOGI',
#  'EURO PIZZA',
#  'GRK',
#  'INATESSO PIZZA BAR CASANO',
#  'MANDUCATIS RUSTICA VIG',
#  'MAYA TAQUERIA',
#  'OMEGA COFFEE SHOP',
#  'PLAY SPORTS BAR',
#  'POPEYES LOUISIANA KITCHEN',
#  'STADIUM PIZZA BAR RESTAURANT',
#  'SUNRISE MART',
#  'THE KATI ROLL COMPANY',
#  "AUNT ANNIE'S",
#  'CAFE CENTRO',
#  'DREDSURFER GRILL',
#  'GINGERS (DOUBLE TREE HOTEL)',
#  'LEFT FIELD CONCESSION STAND',
#  'RIGHT FIELD BEER EXPRESS/PICNIC',
#  'SUITE KITCHEN',
#  'SUNSET PARK DINER & DONUTS',
#  'VILLA MARCELLO',
#  '1617-A NATIONAL BAKERY',
#  'A1 OCHA SUSHI',
#  'CONCESSION STAND 120',
#  'GOSSIPS',
#  'LEE LEE BUBBLE TEA',
#  "NEW DAVE'S",
#  "PIA'S PIZZERIA",
#  'STAND # 110',
#  'STAND #326',
#  'WIN HING CHINESE RESTAURANT',
#  'ARIA',
#  'INTREPID SEA-AIR-SPACE MUSEUM',
#  'RAIZES CHURRASCARIA',
#  'SKYVIEW DINER',
#  'YONG SHENG RESTAURANT',
#  'BLIND PIG',
#  'C. LO CAFE',
#  'GOLDEN CHINA PAVILION',
#  'IL MULINO',
#  'LIBERTY RESTAURANT',
#  'PERA MEDITERRANEAN BRASSERIE',
#  'PHEBES',
#  'RIPPERS',
#  'YU KING BAKERY',
#  "CHUCK E. CHEESE'S",
#  'GARDENIA RESTAURANT',
#  'JEAN DANET FRENCH PASTRY',
#  'KNAPP PIZZA III',
#  'LOS 3 POTRILLOS',
#  'MANOR SUSHI',
#  'RMM LOUNGE',
#  'SING HUA KITCHEN',
#  'THE WEST SHORE INN RESTAURANT',
#  'EL TINA FISH MARKET & SEAFOOD RESTAURANT',
#  "GRINI'S GRILL & RESTAURANT",
#  'LEONIDAS',
#  'LULA BAGEL',
#  'ROSA MEXICANA',
#  'TASTE THE TROPICS ICE CREAM',
#  'HONEYBEE PATISSERIE',
#  'THE RIVER CAFE',
#  'LA LANTERNA DI VITTORIO',
#  'MARKET PLACE (CENTERPLATE)',
#  'METROPOLITAN MUSEUM ROOF TOP GARDEN CAFE',
#  'SALUD PERFECTA',
#  'BAMBOO TAVERN',
#  "BERGER'S ON THE GO",
#  'BIG DADDY CARIBBEAN TASTE',
#  'CAFE RIAZOR',
#  'DELICIOSO RESTAURANT',
#  'DOUBLE FIRE GOURMET',
#  'GENTE',
#  'LEON KITCHEN',
#  'MADISON & VINE',
#  'MAHALO NEW YORK BAKERY',
#  'NY FRESH PIZZA',
#  'PURBIRD',
#  'ROW NYC/DISTRICT M',
#  'TEUTA QEBAPTORE',
#  'AL VICOLETTO',
#  'CAFFE VITA',
#  'CROMPTON ALE HOUSE',
#  'LE FATIMA BAR & GRILL',
#  'MOTHER PUGS SALOON',
#  "HUMRO BHIM'S CAFE,",
#  'BAR GOTO',
#  'BISTRO LES AMIS',
#  'BLACKSTONE  BAR AND GRILL',
#  'DOS TOROS',
#  'KAPPOCK CAFE',
#  'PARKER & QUINN',
#  'HOUSE OF ANTOJITOS',
#  "JOSEPH'S DREAM BURGER",
#  'KRISPY KREME',
#  'LUCKY HOUSE CHINESE KITCHEN',
#  "MAMA TINA'S PIZZA",
#  'NEW YORK UNIVERSITY - KIMMEL STUDENT CENTER CAFETERIA',
#  "O'FLANAGAN'S",
#  "VANESSA'S DUMPLING HOUSE",
#  "CHOP'T",
#  'ELLINGTON IN THE PARK',
#  'JG Melon',
#  'LILY THAI RESTAURANT',
#  'OVERLOOK',
#  'PALADARES BAKERY & RESTAURANT',
#  'THE ORIGINAL PIZZA OF 4TH AVE',
#  'WEI MEI XIAN',
#  'GUARO DOMINICAN RESTAURANT',
#  'JAPAS 38',
#  'LJ PIZZA',
#  'MAGGIE MAYS',
#  'NEUEHOUSE',
#  "WENDY'S",
#  "21 HOME'S KITCHEN",
#  'GOOD KITCHEN SEAFOOD RESTAURANT',
#  "GOODY'S BBQ",
#  'Imperial',
#  'LITUATION LOUNGE',
#  "NATHAN'S FAMOUS",
#  'BRUNO',
#  'DELI & GRILL',
#  'EL CAMION CANTINA',
#  'IVANA PIZZA',
#  'KAI FENG FU DUMPLING HOUSE',
#  'LOCK YARD',
#  "ORIGINAL NAPOLI'S PIZZA",
#  'PIG HEAVEN',
#  'WOOD AND ALES',
#  'Y CAFE',
#  'BISOUX MARKET/WORLD BEAN',
#  'BROOKLYN CAFE 1',
#  'DON PACO LOPEZ PANADERIA',
#  'HBO EDR',
#  'NO PARTNERS',
#  'OOTOYA',
#  'PRIME TAVERN/DELTA TERMINAL',
#  'TAGLIARE PIZZA  DELTA TERMINAL',
#  'WEST BANK CAFE',
#  'DELICIAS BAKERY',
#  'EDO SUSHI TERIYAKI NOODLE',
#  'GEN RESTAURANT',
#  'QUENTIN PIZZA',
#  'WRAP N ROLL',
#  'YI ZHANG FISHBALL',
#  'BATI',
#  'BEIT JEDDO',
#  'BEST WESTERN HOTEL HOSPITALITY HOUSE',
#  'COFFEE SHOP ON 8TH AVE',
#  'JOLIE CANTINA',
#  'KING WOK KITCHEN',
#  'PERDITION',
#  'SOUTH SHORE SWIMMING CLUB',
#  'SUN IN BLOOM',
#  'BLUE FIN',
#  'OSTERIA AL DODGE',
#  "ZANNY'S CAFE",
#  'ZOMBIE HUT',
#  "CODY'S ALE HOUSE GRILL",
#  'FRUCES',
#  'GHANDI CAFE',
#  'LA BROCHETTE STEAKHOUSE.',
#  'SPICE GRILL',
#  "TASTY'S",
#  'TEMPURA MATSUI',
#  "DUNKIN' DONUTS/BASKIN ROBBINS",
#  'HAE WOON DAE RESTAURANT',
#  'LINDA ASIAN KITCHEN',
#  'MESKEREM',
#  "MICHAEL'S MEATBALLS & MARTINIS",
#  "BIG DADDY'S PIZZA",
#  'BRIK BAR LOUNGE & KITCHEN',
#  'CIAO',
#  "DOMINO'S",
#  'EL-OMDA',
#  'EPISTROPHY CAFE',
#  'KAM TUNG RESTAURANT',
#  'MASPETH PIZZA',
#  'PAPA MIKES BRICK OVEN PIZZA',
#  'PIC UP STIX',
#  'PIZZA WAGON',
#  'RUINAS DE COPAN',
#  'THE MEATBALL SHOP',
#  'ALPHA BAKERY',
#  'COLONIA VERDE',
#  'GOLD STAR JERK CENTER',
#  'IVAN RAMEN',
#  'KANAN INDIAN RESTAURANT',
#  'LA GUALACENA BAR & RESTAURANT',
#  'MANHATTAN CENTER',
#  'MI PEQUENA CHOLULA DELI RESTAURANTE',
#  'NEW CHINA RESTAURANT',
#  "SAL'S DELI",
#  'TAQUERIA TLAXCALLI',
#  'TENDER TRAP',
#  'TERRA BLUES',
#  "THE BUTCHER'S DAUGHTER",
#  'WEST CUISINE-ENCHANTMENT BY MARIA',
#  'ALL NATIONS',
#  'BROOKLYN CUPCAKE',
#  'CAFE 58',
#  'ELSA LA REINA DEL CHICHARRON 3',
#  'GP SMOOTHIES & GIFTSHOP',
#  "HENRY'S END",
#  'SAFFRON',
#  'ISLAND CHOIZ RESTAURANT',
#  'BAI DAR CAFE',
#  'BROOKDALE',
#  'CASA MEXICANA',
#  'EASTERN RESTAURANT',
#  'ELI ZABAR',
#  'LE MONDE',
#  "MIGHTY QUINN'S BBQ",
#  'SUTTON CAFE RESTAURANT',
#  "XI'AN FAMOUS FOODS",
#  'AMATA',
#  'BLUEMAIZ',
#  'HEARTLAND BAGELS',
#  'K & D INTERNET CAFE',
#  'ODDFELLOWS ICE CREAM',
#  'SHIRO OF JAPAN',
#  'SOCCER TAVERN',
#  'AGNANTI RESTAURANT',
#  'BLACK SEED BAGELS',
#  'BY THE WAY BAKERY',
#  'CHINA VILLAGE RESTAURANT',
#  'KEENS STEAKHOUSE',
#  'KOSHER HUT OF BROOKLYN',
#  'LA ROSA BAKERY',
#  'MORGAN LIBRARY',
#  'PALM COURT',
#  'SANTA FE',
#  "STICKY'S FINGER JOINT #1",
#  'VALHALLA',
#  'CAFE SAHARA',
#  'CHIRPING CHICKEN',
#  "FREDDY'S SOUL CARIBBEAN RESTAURANT CORP",
#  'QDOBA MEXICAN GRILL',
#  'THE MILLING ROOM',
#  'THE MONKEY ROOM',
#  'DAI HING GARDEN',
#  "FRIEDMAN'S",
#  'GIAN PIERO BAKERY',
#  'HYATT, NY CENTRAL, ROOM SERVICE',
#  'LA BAGUETTE SHOP',
#  'LIBERTY WAREHOUSE',
#  'NEW ASIAN CUISINE',
#  'PIER 79/NY WATERWAY SEATTLE CAFE',
#  'SL GREEN REALTY',
#  'TIAA-CREF CAFETERIA',
#  'NAZ BAKERY & ROTI SHOP',
#  'RESTAURANT TATIANA',
#  'WHEELERS',
#  'GRAND SLAM Banquet Hall',
#  'YAQUE RIVER',
#  '7 STARS RESTAURANT',
#  '888 KITCHEN',
#  'CAFFEE EXPRESS',
#  'CHASERS',
#  'KAM MAN KITCHEN',
#  'NEW HOOD HING CHINESE RESTAURANT',
#  'TRIOMPHE',
#  'WAH YONG KITCHEN',
#  'CIRCLE IN THE SQUARE THEATRE',
#  'COME & GET SUM FISH & CHIPS',
#  'JADE LINDEN RESTAURANT',
#  'KARAOKE DUET 48',
#  'LA ISLA RESTAURANT',
#  'MI CASA BAKERY & COFFEE SHOP',
#  "MICHAEL ANGELO'S BRICK OVEN",
#  'RAYMI/LATIN BEET KITCHEN',
#  'SMASHBURGER',
#  'STUDIO 151',
#  'TRE',
#  '5 DE MAYO',
#  '5TH AVENUE ASIAN TASTE RESTAURANT',
#  'ASTORIA BAGEL SHOP',
#  'DON PICHON RESTAURANT',
#  'KALAMAKI GR',
#  'LEVAIN BAKERY',
#  'LUCKY EIGHT RESTAURANT',
#  'NIGHT LIGHT CAFE',
#  'OASIS CAFE',
#  'PEQUE VINOS + TAPAS',
#  'SPINCITY BILLIARD & CAFE',
#  'TASTE OF ITALY',
#  'THE RITZ-CARLTON PASTRY KITCHEN',
#  'UPRIGHT',
#  'CAFE EIGHTY TWO',
#  'CAFE1 & CAFE 4 (AMERICAN MUSEUM OF NATURAL HISTORY)',
#  'CROWN GRILL AND SALAD',
#  'EL CASTILLO DE JAGUA REST',
#  "HENRICA'S RESTAURANT",
#  'LAMARCA PASTA RESTAURANT',
#  "MOLLY'S",
#  'ONCE UPON A TART',
#  'TURQUOISE KOSHER FISH RESTAURANT',
#  'AFGAN KEBAB AND GRILL',
#  'HOUSING WORKS FOOD',
#  "JOHN MULLIGAN'S FIRESIDE PUB",
#  'PHAYUL RESTAURANT',
#  'SCALINATELLA RESTAURANT',
#  'THE CORNELL CENTER OF NEW YORK',
#  'ANOTHEROOM',
#  'BRUSHSTROKE (30 HUDSON ST)',
#  'IMPERIAL BAKERY',
#  "LUKE'S PIZZA",
#  "MAMA'S COOKING",
#  "MURPHY'S LAW",
#  'NEW SHENG CHINESE KITCHEN',
#  'PLANET WINGS',
#  'SAGAPONACK',
#  'TERIYAKI BURRITO HOUSE',
#  "AMERICAN HERO & SUB'S",
#  'AVE COFFEE HOUSE',
#  'BEDFORD FALLS',
#  "BRANDY'S PIANO BAR",
#  "CONNOLLY'S",
#  'EMPIRE CHINESE RESTAURANT ZHENG',
#  'ESCAPE INTERNATIONAL CUISINE',
#  'FUKU',
#  "JIM'S CHINA KING",
#  'MCDONALDS',
#  "MICHAEL'S PASTRY SHOP",
#  'MYUNG SAN RESTAURANT',
#  'RED LION INN & SUITES',
#  'TUSCANY CAFE',
#  'ULTIMATE BAKERY',
#  'ANYWAY CAFE',
#  'BAGEL CAFE',
#  'BROOKLYNS FINEST PIZZA & RESTAURANT',
#  'CAFE LOUP',
#  "CARRAGHER'S",
#  "DEILINE'S RESTAURANT",
#  "INSIDE PARK AT ST. BART'S",
#  'NEW JING HUI RESTAURANT',
#  'NOL BU FOOD',
#  'SHUNFA BAKERY',
#  'STRANGE LOVE BAR',
#  "TED'S MONTANA GRILL",
#  'BLUE PARROT BAR',
#  'CASABLANCA BAR & GRILL',
#  'EPICE CAFE',
#  'FRESH POND TAVERN',
#  'LINA RESTAURANT',
#  'LOVERAS LOUNGE',
#  'MR CAKE BAKERY & DESSERT',
#  'BRICK OVEN BREAD',
#  'GIMME COFFEE',
#  'MAMAJUANA CAFE / FIESTA CLUB',
#  'BAGELETTE',
#  'CLOCKTOWER',
#  'FRANKIES 570 SPUNTINO',
#  'MASAWA',
#  'MOSS CAFE',
#  'NATIONAL RESTAURANT & COFFEE SHOP',
#  'PAPA YE RESTAURANT',
#  'RIVERDALE SECOND HELPING',
#  'ALADDIN',
#  'AMSTERDAM BILLIARDS',
#  "GINO'S VILLA MONTE",
#  'KUU',
#  'LA MARINA',
#  'LA VILLA PIZZERIA',
#  'PRIME TIME CARIBBEAN BAKERY',
#  'THE MAD DONKEY',
#  'THIRD RAIL COFFEE',
#  'WHISPERS BAR AND RESTAURANT',
#  'COLLEGE POINT MULTIPLEX CINEMAS',
#  'DALLAS BBQ',
#  "LIBRETTO'S PIZZERIA",
#  "MOJITO'S",
#  "RAY'S CANDY STORE",
#  'SHARMEL CATERERS',
#  'VIAND COFFEE SHOP',
#  'BROOK AVENUE DELI & PIZZA',
#  "COOGAN'S",
#  'CROCUS',
#  'HARMONY TERRACE',
#  "HO'BRAH",
#  "JACK'S SLIDERS AND SUSHI",
#  'KULU DESSERTS',
#  'LA NUEVA BAKERY',
#  'MAY LUCK KITCHEN',
#  'OM INDIAN RESTAURANT',
#  'POTBELLY SANDWICH WORKS',
#  'SCHNITZI SCHNITZEL BAR',
#  'SMOKE',
#  'PATZERIA FAMILY & FRIENDS',
#  'SELAMAT PAGI',
#  'WOGIES BAR & GRILL',
#  '224TH CORNER RESTAURANT & BAKERY',
#  'DON PANCHOLO LECHONERA RESTAURANT',
#  'KEATS RESTAURANT',
#  "NEIR'S TAVERN",
#  "NICKOLAS' DELI RESTAURANT",
#  "PATSY'S PIZZERIA",
#  'PETER PAN DONUTS AND PASTRIES',
#  'CAFE 1853',
#  'DAKE SUSHI',
#  'EDERLE TERRACE CAFE',
#  'FLORINDA RESTAURANT',
#  'FU LAI O KITCHEN',
#  'IMMACULEE BAKERY',
#  'JEMZ RESTAURANT',
#  "JOSIE WOOD'S PUB",
#  "K'S CAFETERIA",
#  'THE CORNELIA STREET CAFE',
#  'WEST END HALL BEER GARDEN',
#  'BARBARESCO',
#  'CASA PROMESA',
#  'CHECKERS',
#  'EXTREME BLENDZ (CRUNCH)',
#  'GOURMET GARDEN 8',
#  'GREAT WALL CHINESE CUISINE',
#  "JAKE'S DILEMMA",
#  'JERUSALEM CAFE',
#  'LA SHUK',
#  'MIMI JAPANESE RESTAURANT',
#  'NEW THANKS GIVING CHINESE RESTAURANT',
#  'PINGS',
#  'PINO WINE BAR',
#  'POLPETTE 71',
#  'STAND # 210',
#  'THE BROOKLYN STRATEGIST',
#  'THE LEOPARD AT DES ARTISTES',
#  'THE SPOT CAFE/KOFOO',
#  "THREE BROTHER'S PIZZERIA",
#  'VANGUARD WINE BAR',
#  'YUMMY CHINESE RESTAURANT',
#  'CAFE & RESTAURANT BONGAR',
#  'CLAUDETTE',
#  "JOHNNY'S REEF RESTAURANT",
#  "LOJA'S PIZZA",
#  'MOLO',
#  'PETROSSIAN BOUTIQUE',
#  'THE SHAKESPEARE',
#  'BARCELONA BAR',
#  'FLAVA II',
#  "PEPPER'S CARIBBEAN RESTAURANT AND BAR",
#  'WESTVILLE',
#  'CAMPANIA COAL FIRED PIZZA',
#  'NOWADAYS',
#  'CARIBE RESTAURANT',
#  'CHINA WOK',
#  'DJ REYNOLDS PUB AND RESTAURANT',
#  'FORTUNE COOKIE',
#  'JONGRO BBQ',
#  'LEE XING RESTAURANT',
#  'LISSETT OMAR',
#  'MAGIC WOK',
#  'NUM PANG SANDWICH SHOP',
#  'RADIO STAR',
#  'TARTINERY',
#  'THE BEST ITALIAN PIZZA',
#  'USKUDAR RESTAURANT',
#  'V J  HOT BAGELS',
#  "BABY'S GRILL AND RESTAURANT",
#  'BLACK AND WHITE',
#  "BOB'S YOUR UNCLE",
#  "FRANK & DANNY'S PIZZERIA",
#  'GIUSEPPE PIZZERIA',
#  'JEEPNEY',
#  'LA BAGEL DELIGHT',
#  'OCEAN SIDE RESTAURANT',
#  "BARIO'S @ RICHMOND COUNTY SPORTS COMPLEX",
#  'CAPPUCCINO CAFE',
#  'COZZI PIZZA',
#  'GOUSTARO',
#  'SBARRO',
#  'THE LIGHTHOUSE',
#  "EVERYTHING YOGURT/GRETEL'S PRETZELS",
#  'HONG CHEUNG RESTAURANT',
#  'MURASAKI SUSHI',
#  "NICKY'S JAMAICAN CUISINE",
#  'OAXACA GREENWICH',
#  'PIZZA HUT',
#  'RIVERDALE DINER',
#  'SODA BAR',
#  'TOPAZE RESTAURANT & JERK CHICKEN',
#  'TROPICAL PARADISE RESTAURANT & BAKERY',
#  "AUNTIE ANNE'S PRETZELS",
#  'CHINA GARDEN',
#  'CROWN FRIED CHICKEN',
#  'DRAFT BARN',
#  'INDIE FOOD AND WINE',
#  'LE VIET CAFE',
#  'MILLE-FEUILLE BAKERY',
#  "SCAVELLO'S ON THE ISLAND",
#  'UPSTAIRS LOUNGE THE KIMBERLY HOTEL/ BISTANGO',
#  'GREENPOINT BEER & ALE',
#  'AUSTIN HOUSE',
#  "BEN & JERRY'S",
#  'CARIDAD',
#  'CHEF YU / AZUKI',
#  'IL CORALLO',
#  'JALAPENO DELI',
#  'KOBEYAKI',
#  'KUM WEI KITCHEN',
#  'LEGEND',
#  'LONG ISLAND UNIVERSITY - BLACKBIRD CAFE',
#  'MARINA GOURMET DELI.',
#  'NEW CHINA DELIGHT',
#  "O'BRIENS",
#  "PADDY MAGUIRE'S ALE HOUSE",
#  'THE LEXINGTON SOCIAL',
#  'U CAFE',
#  "WIMPY'S RESTAURANT",
#  'BESO RESTAURANT AND BAR',
#  'BLOCKHEADS',
#  'BOCCA DI BACCO',
#  'BUFFALO WILD WINGS',
#  'GOLDEN WOKS',
#  'GRANDCHAMPS',
#  'IL BAMBINO',
#  'LA TARTE FLAMBEE',
#  'MACCHINA NYC',
#  'OVENLY',
#  "PATRICIA'S",
#  "ROBERTA'S PIZZA",
#  'SANFORDS RESTAURANT',
#  "SARGE'S",
#  'SCAGLIONE BROTHERS BAKERY',
#  'TAKUMI TACO',
#  "VINNY'S LUNCHBOX",
#  'WILD GINGER VEGETARIAN KITCHEN',
#  'ANNA MARIA PIZZA PASTA',
#  'BELLA PIZZA & RESTAURANT',
#  'BK JANI',
#  'CROISSANTERIA',
#  'DON PANCHO VILLA RESTAURANT',
#  'GOOD TASTE #1',
#  'HAVELI FINE INDIAN CUISINE',
#  'HOT KITCHEN SICHUAN STYLE',
#  'LA BELLA MARIELLA',
#  'LUPITA RESTAURANT',
#  'Le Bernardin Priv̩/Wine Bar',
#  'MACARON',
#  'MEI YA KITCHEN',
#  'MORNINGSTAR RESTAURANT',
#  'NIGHT MARKET BBQ',
#  'SILHOUETTE RESTAURANT LOUNGE',
#  'TRA DI NOI',
#  'XIN LI',
#  'YANKEE PIZZA RESTAURANT',
#  'BEMBE',
#  'BRAVO PIZZA',
#  'CITIGROUP CONFERENCE DINING',
#  'PYE BOAT NOODLE',
#  'STUDIO 299',
#  'VISTA SKY LOUNGE & CATERING (SHERATON FOUR POINTS)',
#  'WO HOP 17',
#  'CHEN WON DIM SUM & BAKERY',
#  "NORA'S PARK BENCH CAFE",
#  'QUEEN SHEEBA RESTAURANT',
#  'AZUKI',
#  'CAFFE NOI ESPRESSO BAR',
#  'CAKOR RESTAURANT',
#  'COCO FRESH TEA & JUICE',
#  'EASY CORNER RESTAURANT & GRILL',
#  'FUSION EAST',
#  'GONG CHA',
#  'HAPPY GARDEN',
#  'HUA HUI BAKERY',
#  'MARUZZELLA',
#  'MAZI NIGHTCLUB',
#  'MEX CARROLL DINER',
#  'NICK GARDEN COFFEE SHOP',
#  'PEACHES JAMAICAN RESTAURANT',
#  'PICASSO PIZZERIA',
#  "SAC'S PIZZA PLACE",
#  'WOORIJIP',
#  'ZEREGA AVENUE DELI',
#  'ALITALIA MICHELANGELO LOUNGE',
#  'AMALI MOU',
#  'BANN',
#  "BLOCKHEAD'S MEXICAN DINER",
#  'CASCABEL TAQUERIA',
#  'DREAM PIZZA',
#  'HALE & HEARTY SOUP',
#  'HOURGLASS TAVERN',
#  'IL TINELLO RISTORANTE',
#  'JUN-MEN RAMEN BAR',
#  'PZA',
#  "RUDY'S DELI RESTAURANT",
#  'RUSSIAN SAMOVAR',
#  'ABC KITCHEN',
#  ...]

# %%
chain = store_num.loc[store_num['camis_count'] > 10]
chain_rank = chain.groupby(['dba'])['camis_count'].sum().reset_index().sort_values(['inspection_year','camis_count'],ascending=False)

print(len(list(chain_rank['dba'].unique())))
chain_list = list(chain_rank['dba'].unique())[:10]
chain_rank
# Out:
# 173
#      inspection_year                                    dba  camis_count
# 189             2019                                 SUBWAY          150
# 161             2019                         DUNKIN' DONUTS          122
# 168             2019                  KENNEDY FRIED CHICKEN           55
# 188             2019                              STARBUCKS           37
# 175             2019                             MCDONALD'S           24
# 180             2019                    PHO BANG RESTAURANT           15
# 151             2019                         BEANS & BAGELS           14
# 163             2019                      GO BELIEVE BAKERY           14
# 153             2019                             CAFE CHILI           13
# 159             2019                           DECCAN SPICE           13
# 164             2019                      GRANDMA'S DIM SUM           13
# 166             2019                           ICHIBA RAMEN           13
# 187             2019                SEIS VECINOS RESTAURANT           13
# 195             2019                               YUMMY 88           13
# 157             2019                      COM TAM NINH KIEU           12
# 165             2019                         HALAL MUNCHIES           12
# 169             2019                                    KFC           12
# 174             2019                     MASHA AND THE BEAR           12
# 178             2019                    NEW WONG RESTAURANT           12
# 181             2019              POPEYES LOUISIANA KITCHEN           12
# 183             2019              QUEENS SEAFOOD RESTAURANT           12
# 186             2019                         SAVOUR SICHUAN           12
# 152             2019                            BentOn Cafe           11
# 154             2019                             CAFE HADAR           11
# 155             2019                             CAFE WATER           11
# 156             2019                   CENTURY SUPER BUFFET           11
# 158             2019                    CROWN FRIED CHICKEN           11
# 160             2019                    DON ALEX RESTAURANT           11
# 162             2019                     FRITZIES BAKE SHOP           11
# 167             2019                     KEFI GREEK CUISINE           11
# ..               ...                                    ...          ...
# 22              2016                             MCDONALD'S           25
# 10              2016                               DOMINO'S           24
# 12              2016          EL TAPATIO MEXICAN RESTAURANT           14
# 28              2016                          THE AINSWORTH           14
# 29              2016                      THE KING COLE BAR           14
# 6               2016                    BROADWAY RESTAURANT           13
# 9               2016                        DOJO RESTAURANT           13
# 8               2016                      CASCABEL TAQUERIA           12
# 17              2016                        IRON CHEF HOUSE           12
# 18              2016            KABAYAN FILIPINO RESTAURANT           12
# 20              2016                MAX BAKERY & RESTAURANT           12
# 21              2016              MAX BRENNER CHOCOLATE BAR           12
# 25              2016   SHINJUNG GALBI BBQ KOREAN RESTAURANT           12
# 5               2016                       ACCRA RESTAURANT           11
# 7               2016                          BROOKLYN CRAB           11
# 13              2016                               FLAVA II           11
# 14              2016  GOLDEN KRUST CARIBBEAN BAKERY & GRILL           11
# 15              2016                    GRAMERCY  ALE HOUSE           11
# 16              2016                      IL FORNO/IRON BAR           11
# 19              2016                         LILLY O'BRIENS           11
# 23              2016                        PARK VIEW DINER           11
# 24              2016                           POLLO D' ORO           11
# 26              2016                              STARBUCKS           11
# 30              2016          THE WEST SHORE INN RESTAURANT           11
# 31              2016               TOMO JAPANESE RESTAURANT           11
# 1               2015                         DUNKIN' DONUTS           16
# 2               2015                                   NANO           12
# 4               2015   SOLDIERS CARIBBEAN BUFFET RESTAURANT           12
# 0               2015      AL HORNO LEAN MEXICAN KITCHEN INC           11
# 3               2015                          SKYLINE DINER           11
#
# [196 rows x 3 columns]

# %%
local_dict = {'LOCAL BUSINESS':local_list}

# %%
store_count = store_num.pivot(index='inspection_date',columns='dba',values='camis_count').fillna(0)
store_count
# Out:
# dba              #1 Chinese Restaurant  #1 GARDEN CHINESE RESTAURANT  \
# inspection_date
# 2015                               0.0                           0.0
# 2016                               3.0                           0.0
# 2017                               0.0                           0.0
# 2018                              17.0                           9.0
# 2019                               2.0                           5.0
#
# dba              #1 Natural Juice Bar  #1 SABOR LATINO RESTAURANT  \
# inspection_date
# 2015                              0.0                         5.0
# 2016                              4.0                        15.0
# 2017                              2.0                         2.0
# 2018                              2.0                        10.0
# 2019                              0.0                         0.0
#
# dba              $ 1 SLICE PIZZA  $1 PIZZA  $1.25 PIZZA  $5 TO $9 RESTAURANT  \
# inspection_date
# 2015                         0.0       0.0          0.0                  0.0
# 2016                         0.0       0.0          0.0                  0.0
# 2017                         2.0       0.0          8.0                  0.0
# 2018                        19.0       0.0         16.0                  7.0
# 2019                         0.0       4.0          0.0                  0.0
#
# dba              & PIZZA  'CESCA          ...           ZZ'S PIZZA & GRILL  \
# inspection_date                           ...
# 2015                 0.0     0.0          ...                          0.0
# 2016                 0.0     0.0          ...                         10.0
# 2017                 7.0     6.0          ...                          9.0
# 2018                 6.0     3.0          ...                          7.0
# 2019                 8.0     0.0          ...                          4.0
#
# dba              Zenith Thai  Zenon Taverna  cafe paulette  cloud social  \
# inspection_date
# 2015                     0.0            0.0            0.0           3.0
# 2016                     0.0            2.0            2.0           2.0
# 2017                     0.0            0.0            5.0           2.0
# 2018                     5.0            7.0            3.0           2.0
# 2019                     0.0            0.0            4.0           0.0
#
# dba              iPizzaNY  inthemix jamaican & southern cuisine  \
# inspection_date
# 2015                  0.0                                   0.0
# 2016                  0.0                                   0.0
# 2017                  0.0                                   0.0
# 2018                  0.0                                   0.0
# 2019                  9.0                                   3.0
#
# dba              matchpointnyc  tutto il giorno  wok and roll kitchen
# inspection_date
# 2015                       0.0              0.0                   0.0
# 2016                       5.0              3.0                   0.0
# 2017                       6.0              2.0                   0.0
# 2018                       5.0              6.0                   0.0
# 2019                       2.0              0.0                   2.0
#
# [5 rows x 20545 columns]

# %%
for key in local_dict:
    local_business = store_count[local_dict[key]].agg("sum", axis="columns")
local_business
# Out:
# inspection_date
# 2015     10683.0
# 2016     76629.0
# 2017     92198.0
# 2018    138576.0
# 2019     59016.0
# dtype: float64

# %%
chain = store_count[chain_list]
chain
# Out:
# dba              DUNKIN' DONUTS  BURGER KING  CHECKERS  \
# inspection_date
# 2015                      220.0         25.0      18.0
# 2016                      898.0        195.0     104.0
# 2017                     1255.0        280.0     162.0
# 2018                     1379.0        309.0     148.0
# 2019                      502.0        132.0      29.0
#
# dba              CHIPOTLE MEXICAN GRILL  CROWN FRIED CHICKEN  DOMINO'S  \
# inspection_date
# 2015                               59.0                  9.0      59.0
# 2016                              187.0                154.0     265.0
# 2017                              225.0                211.0     322.0
# 2018                              186.0                438.0     281.0
# 2019                               70.0                150.0     118.0
#
# dba              DUNKIN' DONUTS, BASKIN ROBBINS  \
# inspection_date
# 2015                                       67.0
# 2016                                      230.0
# 2017                                      368.0
# 2018                                      310.0
# 2019                                      141.0
#
# dba              GOLDEN KRUST CARIBBEAN BAKERY & GRILL  KENNEDY FRIED CHICKEN  \
# inspection_date
# 2015                                              37.0                   44.0
# 2016                                             197.0                  238.0
# 2017                                             233.0                  264.0
# 2018                                             297.0                  474.0
# 2019                                              98.0                  237.0
#
# dba                KFC       ...        WENDY'S  BAREBURGER  PRET A MANGER  \
# inspection_date              ...
# 2015              12.0       ...            8.0        23.0           24.0
# 2016             119.0       ...          119.0        61.0           73.0
# 2017             197.0       ...          143.0       104.0          123.0
# 2018             174.0       ...          118.0        79.0          107.0
# 2019              96.0       ...           61.0        56.0           45.0
#
# dba              VIVI BUBBLE TEA  BREAD & BUTTER  CARVEL ICE CREAM  \
# inspection_date
# 2015                         4.0             0.0              17.0
# 2016                        84.0            32.0              88.0
# 2017                       104.0            99.0              96.0
# 2018                       129.0           103.0             102.0
# 2019                        50.0            31.0              35.0
#
# dba              JUST SALAD  LITTLE CAESARS  PAPA JOHN'S  PARIS BAGUETTE
# inspection_date
# 2015                    6.0            17.0          7.0             0.0
# 2016                   47.0            77.0         87.0            56.0
# 2017                   65.0            73.0         87.0            62.0
# 2018                  129.0           102.0        167.0           142.0
# 2019                   33.0            32.0         66.0            55.0
#
# [5 rows x 25 columns]

# %%
cds_chain = ColumnDataSource(chain)
cds_chain.column_names
# Out:
# ['inspection_date',
#  "DUNKIN' DONUTS",
#  'BURGER KING',
#  'CHECKERS',
#  'CHIPOTLE MEXICAN GRILL',
#  'CROWN FRIED CHICKEN',
#  "DOMINO'S",
#  "DUNKIN' DONUTS, BASKIN ROBBINS",
#  'GOLDEN KRUST CARIBBEAN BAKERY & GRILL',
#  'KENNEDY FRIED CHICKEN',
#  'KFC',
#  'LE PAIN QUOTIDIEN',
#  "MCDONALD'S",
#  'POPEYES LOUISIANA KITCHEN',
#  'STARBUCKS',
#  'SUBWAY',
#  "WENDY'S",
#  'BAREBURGER',
#  'PRET A MANGER',
#  'VIVI BUBBLE TEA',
#  'BREAD & BUTTER',
#  'CARVEL ICE CREAM',
#  'JUST SALAD',
#  'LITTLE CAESARS',
#  "PAPA JOHN'S",
#  'PARIS BAGUETTE']

# %%
chart = figure(height = 600, width = 1500,
               title = "Number of Locations",
               x_axis_type = "linear",
               tools = "pan,wheel_zoom,box_zoom,reset,save,zoom_in,zoom_out,lasso_select")

# %%
line_list = list(cds_chain.column_names)[2:]
line_color = ['#8dd3c7','#ffffb3','#bebada','#fb8072',
              '#80b1d3','#fdb462','#b3de69','#fccde5',
              '#d9d9d9','#bc80bd','#ccebc5','#ffed6f',
              '#a6cee3','#1f78b4','#b2df8a','#33a02c',
              '#fb9a99','#e31a1c','#fdbf6f','#ff7f00',
              '#cab2d6','#6a3d9a','#ffff99','#b15928',
              '#000000']
if "inspection_date" in line_list: 
    line_list.remove("inspection_date")
print(len(line_list))
print(len(line_color))
print(line_list)
# Out:
# 24
# 25
# ['BURGER KING', 'CHECKERS', 'CHIPOTLE MEXICAN GRILL', 'CROWN FRIED CHICKEN', "DOMINO'S", "DUNKIN' DONUTS, BASKIN ROBBINS", 'GOLDEN KRUST CARIBBEAN BAKERY & GRILL', 'KENNEDY FRIED CHICKEN', 'KFC', 'LE PAIN QUOTIDIEN', "MCDONALD'S", 'POPEYES LOUISIANA KITCHEN', 'STARBUCKS', 'SUBWAY', "WENDY'S", 'BAREBURGER', 'PRET A MANGER', 'VIVI BUBBLE TEA', 'BREAD & BUTTER', 'CARVEL ICE CREAM', 'JUST SALAD', 'LITTLE CAESARS', "PAPA JOHN'S", 'PARIS BAGUETTE']

# %%
for i in range(len(line_list)):
    chart.line(x = "inspection_date", y = line_list[i], color = line_color[i], 
               legend = value(line_list[i]), source = cds_chain)
chart.legend.click_policy = "hide"
show(chart)
# Out:
#   <div class="bk-root" id="8fd8ab09-1ce9-4060-b374-725df1277d9f"></div>

# %%
for i in range(len(line_list)):
    print(line_list[i])
# Out:
# DUNKIN' DONUTS
# BURGER KING
# CHECKERS
# CHIPOTLE MEXICAN GRILL
# CROWN FRIED CHICKEN
# DOMINO'S
# DUNKIN' DONUTS, BASKIN ROBBINS
# GOLDEN KRUST CARIBBEAN BAKERY & GRILL
# KENNEDY FRIED CHICKEN
# KFC
# LE PAIN QUOTIDIEN
# MCDONALD'S
# POPEYES LOUISIANA KITCHEN
# STARBUCKS
# SUBWAY
# WENDY'S
# BAREBURGER
# PRET A MANGER
# VIVI BUBBLE TEA
# BREAD & BUTTER
# CARVEL ICE CREAM
# JUST SALAD
# LITTLE CAESARS
# PAPA JOHN'S
# PARIS BAGUETTE
